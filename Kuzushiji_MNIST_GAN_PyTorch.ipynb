# %% [markdown]
# <a href="https://colab.research.google.com/github/kannankumar/jupyter-notebooks/blob/kuzushiji-mnist-gan/Kuzushiji_MNIST_GAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Kuzishiji Generation
# ## Generating handdrawn old cursive Japanese script
#
# In this notebook, we'll be building a generative adversarial network (GAN) trained on the KMNIST dataset. From this, we'll be able to generate new handwritten cursive script!
#
# If you're interested in generating only new images, you can throw out the discriminator after training. In this notebook, I'll show you how to define and train these adversarial networks in PyTorch and generate new images!

# %%
# %matplotlib inline

import numpy as np
import torch
import matplotlib.pyplot as plt

# %%
from torchvision import datasets
import torchvision.transforms as transforms

# number of subprocesses to use for data loading
num_workers = 0
# how many samples per batch to load
batch_size = 64

# convert data to torch.FloatTensor
transform = transforms.ToTensor()

# get the training datasets
train_data = datasets.KMNIST(root='data', train=True,
                                   download=True, transform=transform)

# prepare data loader
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
                                           num_workers=num_workers)
# Out:
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/train-images-idx3-ubyte.gz to data/KMNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting data/KMNIST/raw/train-images-idx3-ubyte.gz to data/KMNIST/raw
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/train-labels-idx1-ubyte.gz to data/KMNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting data/KMNIST/raw/train-labels-idx1-ubyte.gz to data/KMNIST/raw
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/t10k-images-idx3-ubyte.gz to data/KMNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting data/KMNIST/raw/t10k-images-idx3-ubyte.gz to data/KMNIST/raw
# Downloading http://codh.rois.ac.jp/kmnist/dataset/kmnist/t10k-labels-idx1-ubyte.gz to data/KMNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting data/KMNIST/raw/t10k-labels-idx1-ubyte.gz to data/KMNIST/raw
# Processing...
# Done!

# %% [markdown]
# ### Visualize the data

# %%
# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy()

# get one image from the batch
img = np.squeeze(images[6])

fig = plt.figure(figsize = (3,3)) 
ax = fig.add_subplot(111)
ax.imshow(img, cmap='gray')

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.

# %% [markdown]
# ## Discriminator
#
# The discriminator network is going to be a pretty typical linear classifier. To make this network a universal function approximator, we'll need at least one hidden layer, and these hidden layers should have one key attribute:
# > All hidden layers will have a [Leaky ReLu](https://pytorch.org/docs/stable/nn.html#torch.nn.LeakyReLU) activation function applied to their outputs.
#
# <img src='assets/gan_network.png' width=70% />
#
# #### Leaky ReLu
#
# We should use a leaky ReLU to allow gradients to flow backwards through the layer unimpeded. A leaky ReLU is like a normal ReLU, except that there is a small non-zero output for negative input values.
#
# <img src='assets/leaky_relu.png' width=40% />
#
# #### Sigmoid Output
#
# We'll also take the approach of using a more numerically stable loss function on the outputs. Recall that we want the discriminator to output a value 0-1 indicating whether an image is _real or fake_.
# > We will ultimately use [BCEWithLogitsLoss](https://pytorch.org/docs/stable/nn.html#bcewithlogitsloss), which combines a `sigmoid` activation function **and** and binary cross entropy loss in one function.
#
# So, our final output layer should not have any activation function applied to it.

# %%
import torch.nn as nn
import torch.nn.functional as F

class Discriminator(nn.Module):

    def __init__(self, input_size, hidden_dim, output_size):
        super(Discriminator, self).__init__()
        
        # define hidden linear layers
        self.fc1 = nn.Linear(input_size, hidden_dim*4)
        self.fc2 = nn.Linear(hidden_dim*4, hidden_dim*2)
        self.fc3 = nn.Linear(hidden_dim*2, hidden_dim)
        
        # final fully-connected layer
        self.fc4 = nn.Linear(hidden_dim, output_size)
        
        # dropout layer 
        self.dropout = nn.Dropout(0.3)
        
        
    def forward(self, x):
        # flatten image
        x = x.view(-1, 28*28)
        # all hidden layers
        x = F.leaky_relu(self.fc1(x), 0.2) # (input, negative_slope=0.2)
        x = self.dropout(x)
        x = F.leaky_relu(self.fc2(x), 0.2)
        x = self.dropout(x)
        x = F.leaky_relu(self.fc3(x), 0.2)
        x = self.dropout(x)
        # final layer
        out = self.fc4(x)

        return out

# %% [markdown]
# ## Generator
#
# The generator network will be almost exactly the same as the discriminator network, except that we're applying a [tanh activation function](https://pytorch.org/docs/stable/nn.html#tanh) to our output layer.
#
# #### tanh Output
# The generator has been found to perform the best with $tanh$ for the generator output, which scales the output to be between -1 and 1, instead of 0 and 1.
#
# <img src='assets/tanh_fn.png' width=40% />
#
# Recall that we also want these outputs to be comparable to the *real* input pixel values, which are read in as normalized values between 0 and 1.
# > So, we'll also have to **scale our real input images to have pixel values between -1 and 1** when we train the discriminator.
#
# I'll do this in the training loop, later on.

# %%
class Generator(nn.Module):

    def __init__(self, input_size, hidden_dim, output_size):
        super(Generator, self).__init__()
        
        # define hidden linear layers
        self.fc1 = nn.Linear(input_size, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim*2)
        self.fc3 = nn.Linear(hidden_dim*2, hidden_dim*4)
        
        # final fully-connected layer
        self.fc4 = nn.Linear(hidden_dim*4, output_size)
        
        # dropout layer 
        self.dropout = nn.Dropout(0.3)

    def forward(self, x):
        # all hidden layers
        x = F.leaky_relu(self.fc1(x), 0.2) # (input, negative_slope=0.2)
        x = self.dropout(x)
        x = F.leaky_relu(self.fc2(x), 0.2)
        x = self.dropout(x)
        x = F.leaky_relu(self.fc3(x), 0.2)
        x = self.dropout(x)
        # final layer with tanh applied
        out = F.tanh(self.fc4(x))

        return out

# %% [markdown]
# ## Model hyperparameters

# %%
# Discriminator hyperparams

# Size of input image to discriminator (28*28)
input_size = 784
# Size of discriminator output (real or fake)
d_output_size = 1
# Size of last hidden layer in the discriminator
d_hidden_size = 32

# Generator hyperparams

# Size of latent vector to give to generator
z_size = 100
# Size of discriminator output (generated image)
g_output_size = 784
# Size of first hidden layer in the generator
g_hidden_size = 32

# %% [markdown]
# ## Build complete network
#
# Now we're instantiating the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
# instantiate discriminator and generator
D = Discriminator(input_size, d_hidden_size, d_output_size)
G = Generator(z_size, g_hidden_size, g_output_size)

# check that they are as you expect
print(D)
print()
print(G)
# Out:
# Discriminator(
#   (fc1): Linear(in_features=784, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=32, bias=True)
#   (fc4): Linear(in_features=32, out_features=1, bias=True)
#   (dropout): Dropout(p=0.3, inplace=False)
# )
#
# Generator(
#   (fc1): Linear(in_features=100, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=128, bias=True)
#   (fc4): Linear(in_features=128, out_features=784, bias=True)
#   (dropout): Dropout(p=0.3, inplace=False)
# )

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
# <img src='assets/gan_pipeline.png' width=70% />
#
# The losses will by binary cross entropy loss with logits, which we can get with [BCEWithLogitsLoss](https://pytorch.org/docs/stable/nn.html#bcewithlogitsloss). This combines a `sigmoid` activation function **and** and binary cross entropy loss in one function.
#
# For the real images, we want `D(real_images) = 1`. That is, we want the discriminator to classify the the real images with a label = 1, indicating that these are real. To help the discriminator generalize better, the labels are **reduced a bit from 1.0 to 0.9**. For this, we'll use the parameter `smooth`; if True, then we should smooth our labels. In PyTorch, this looks like `labels = torch.ones(size) * 0.9`
#
# The discriminator loss for the fake data is similar. We want `D(fake_images) = 0`, where the fake images are the _generator output_, `fake_images = G(z)`.
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get `D(fake_images) = 1`. In this case, the labels are **flipped** to represent that the generator is trying to fool the discriminator into thinking that the images it generates (fakes) are real!

# %%
# Calculate losses
def real_loss(D_out, smooth=False):
    batch_size = D_out.size(0)
    # label smoothing
    if smooth:
        # smooth, real labels = 0.9
        labels = torch.ones(batch_size)*0.9
    else:
        labels = torch.ones(batch_size) # real labels = 1
        
    # numerically stable loss
    criterion = nn.BCEWithLogitsLoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

def fake_loss(D_out):
    batch_size = D_out.size(0)
    labels = torch.zeros(batch_size) # fake labels = 0
    criterion = nn.BCEWithLogitsLoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

# %% [markdown]
# ## Optimizers
#
# We want to update the generator and discriminator variables separately. So, we'll define two separate Adam optimizers.

# %%
import torch.optim as optim

# Optimizers
lr = 0.002

# Create optimizers for the discriminator and generator
d_optimizer = optim.Adam(D.parameters(), lr)
g_optimizer = optim.Adam(G.parameters(), lr)

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. We'll use our functions `real_loss` and `fake_loss` to help us calculate the discriminator losses in all of the following cases.
#
# ### Discriminator training
# 1. Compute the discriminator loss on real, training images
# 2. Generate fake images
# 3. Compute the discriminator loss on fake, generated images
# 4. Add up real and fake loss
# 5. Perform backpropagation + an optimization step to update the discriminator's weights
#
# ### Generator training
# 1. Generate fake images
# 2. Compute the discriminator loss on fake images, using **flipped** labels!
# 3. Perform backpropagation + an optimization step to update the generator's weights
#
# #### Saving Samples
#
# As we train, we'll also print out some loss statistics and save some generated "fake" samples.

# %%
import pickle as pkl

# training hyperparams
num_epochs = 500

# keep track of loss and generated, "fake" samples
samples = []
losses = []

print_every = 400

# Get some fixed data for sampling. These are images that are held
# constant throughout training, and allow us to inspect the model's performance
sample_size=16
fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
fixed_z = torch.from_numpy(fixed_z).float()

# train the network
D.train()
G.train()
for epoch in range(num_epochs):
    
    for batch_i, (real_images, _) in enumerate(train_loader):
                
        batch_size = real_images.size(0)
        
        ## Important rescaling step ## 
        real_images = real_images*2 - 1  # rescale input images from [0,1) to [-1, 1)
        
        # ============================================
        #            TRAIN THE DISCRIMINATOR
        # ============================================
        
        d_optimizer.zero_grad()
        
        # 1. Train with real images

        # Compute the discriminator losses on real images 
        # smooth the real labels
        D_real = D(real_images)
        d_real_loss = real_loss(D_real, smooth=True)
        
        # 2. Train with fake images
        
        # Generate fake images
        z = np.random.uniform(-1, 1, size=(batch_size, z_size))
        z = torch.from_numpy(z).float()
        fake_images = G(z)
        
        # Compute the discriminator losses on fake images        
        D_fake = D(fake_images)
        d_fake_loss = fake_loss(D_fake)
        
        # add up loss and perform backprop
        d_loss = d_real_loss + d_fake_loss
        d_loss.backward()
        d_optimizer.step()
        
        
        # =========================================
        #            TRAIN THE GENERATOR
        # =========================================
        g_optimizer.zero_grad()
        
        # 1. Train with fake images and flipped labels
        
        # Generate fake images
        z = np.random.uniform(-1, 1, size=(batch_size, z_size))
        z = torch.from_numpy(z).float()
        fake_images = G(z)
        
        # Compute the discriminator losses on fake images 
        # using flipped labels!
        D_fake = D(fake_images)
        g_loss = real_loss(D_fake) # use real loss to flip labels
        
        # perform backprop
        g_loss.backward()
        g_optimizer.step()

        # Print some loss stats
        if batch_i % print_every == 0:
            # print discriminator and generator loss
            print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                    epoch+1, num_epochs, d_loss.item(), g_loss.item()))

    
    ## AFTER EACH EPOCH##
    # append discriminator loss and generator loss
    losses.append((d_loss.item(), g_loss.item()))
    
    # generate and save sample, fake images
    G.eval() # eval mode for generating samples
    samples_z = G(fixed_z)
    samples.append(samples_z)
    G.train() # back to train mode


# Save training generator samples
with open('train_samples.pkl', 'wb') as f:
    pkl.dump(samples, f)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1340: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Epoch [    1/  500] | d_loss: 1.3843 | g_loss: 0.7745
# Epoch [    1/  500] | d_loss: 1.0199 | g_loss: 2.3894
# Epoch [    1/  500] | d_loss: 0.8806 | g_loss: 3.3590
# Epoch [    2/  500] | d_loss: 1.1864 | g_loss: 1.6670
# Epoch [    2/  500] | d_loss: 1.1579 | g_loss: 1.2377
# Epoch [    2/  500] | d_loss: 1.0386 | g_loss: 1.9943
# Epoch [    3/  500] | d_loss: 1.2861 | g_loss: 1.5848
# Epoch [    3/  500] | d_loss: 1.2837 | g_loss: 1.0311
# Epoch [    3/  500] | d_loss: 1.2966 | g_loss: 1.1812
# Epoch [    4/  500] | d_loss: 1.0086 | g_loss: 1.5354
# Epoch [    4/  500] | d_loss: 1.0570 | g_loss: 1.3172
# Epoch [    4/  500] | d_loss: 1.0492 | g_loss: 1.9631
# Epoch [    5/  500] | d_loss: 0.9396 | g_loss: 2.6279
# Epoch [    5/  500] | d_loss: 1.2218 | g_loss: 1.9732
# Epoch [    5/  500] | d_loss: 1.1564 | g_loss: 1.6359
# Epoch [    6/  500] | d_loss: 0.9228 | g_loss: 1.8019
# Epoch [    6/  500] | d_loss: 1.1425 | g_loss: 1.5903
# Epoch [    6/  500] | d_loss: 1.3004 | g_loss: 2.3539
# Epoch [    7/  500] | d_loss: 1.0428 | g_loss: 2.1014
# Epoch [    7/  500] | d_loss: 1.0973 | g_loss: 1.9284
# Epoch [    7/  500] | d_loss: 1.0812 | g_loss: 3.5730
# Epoch [    8/  500] | d_loss: 1.1586 | g_loss: 1.3813
# Epoch [    8/  500] | d_loss: 1.1533 | g_loss: 1.6277
# Epoch [    8/  500] | d_loss: 1.1861 | g_loss: 1.4899
# Epoch [    9/  500] | d_loss: 0.9109 | g_loss: 2.0877
# Epoch [    9/  500] | d_loss: 0.9362 | g_loss: 2.2205
# Epoch [    9/  500] | d_loss: 1.1452 | g_loss: 1.3098
# Epoch [   10/  500] | d_loss: 0.9849 | g_loss: 1.7889
# Epoch [   10/  500] | d_loss: 0.9778 | g_loss: 2.8785
# Epoch [   10/  500] | d_loss: 1.0352 | g_loss: 2.0142
# Epoch [   11/  500] | d_loss: 1.1784 | g_loss: 1.2433
# Epoch [   11/  500] | d_loss: 0.9440 | g_loss: 2.1582
# Epoch [   11/  500] | d_loss: 1.1808 | g_loss: 1.2940
# Epoch [   12/  500] | d_loss: 1.2003 | g_loss: 2.2900
# Epoch [   12/  500] | d_loss: 1.2037 | g_loss: 1.4413
# Epoch [   12/  500] | d_loss: 1.2796 | g_loss: 1.2974
# Epoch [   13/  500] | d_loss: 1.1664 | g_loss: 1.3368
# Epoch [   13/  500] | d_loss: 1.2669 | g_loss: 1.1559
# Epoch [   13/  500] | d_loss: 1.2276 | g_loss: 1.1556
# Epoch [   14/  500] | d_loss: 1.2019 | g_loss: 1.3763
# Epoch [   14/  500] | d_loss: 1.2258 | g_loss: 1.3326
# Epoch [   14/  500] | d_loss: 1.1813 | g_loss: 1.1507
# Epoch [   15/  500] | d_loss: 1.2635 | g_loss: 1.1745
# Epoch [   15/  500] | d_loss: 1.2650 | g_loss: 1.0765
# Epoch [   15/  500] | d_loss: 1.2885 | g_loss: 1.1326
# Epoch [   16/  500] | d_loss: 1.2252 | g_loss: 0.9956
# Epoch [   16/  500] | d_loss: 1.3000 | g_loss: 1.0471
# Epoch [   16/  500] | d_loss: 1.2225 | g_loss: 1.1263
# Epoch [   17/  500] | d_loss: 1.2223 | g_loss: 0.9783
# Epoch [   17/  500] | d_loss: 1.3406 | g_loss: 0.9269
# Epoch [   17/  500] | d_loss: 1.0735 | g_loss: 1.5531
# Epoch [   18/  500] | d_loss: 1.2030 | g_loss: 1.2849
# Epoch [   18/  500] | d_loss: 1.1622 | g_loss: 1.1668
# Epoch [   18/  500] | d_loss: 1.1916 | g_loss: 1.1457
# Epoch [   19/  500] | d_loss: 1.2649 | g_loss: 1.2842
# Epoch [   19/  500] | d_loss: 1.2276 | g_loss: 1.5106
# Epoch [   19/  500] | d_loss: 1.2941 | g_loss: 1.0038
# Epoch [   20/  500] | d_loss: 1.2531 | g_loss: 1.0613
# Epoch [   20/  500] | d_loss: 1.2080 | g_loss: 1.0016
# Epoch [   20/  500] | d_loss: 1.1889 | g_loss: 1.1429
# Epoch [   21/  500] | d_loss: 1.1558 | g_loss: 1.3710
# Epoch [   21/  500] | d_loss: 1.2369 | g_loss: 1.6199
# Epoch [   21/  500] | d_loss: 1.3692 | g_loss: 1.2046
# Epoch [   22/  500] | d_loss: 1.2570 | g_loss: 1.3609
# Epoch [   22/  500] | d_loss: 1.1445 | g_loss: 1.3346
# Epoch [   22/  500] | d_loss: 1.1901 | g_loss: 1.3866
# Epoch [   23/  500] | d_loss: 1.2918 | g_loss: 1.4753
# Epoch [   23/  500] | d_loss: 1.2587 | g_loss: 1.0656
# Epoch [   23/  500] | d_loss: 1.2306 | g_loss: 1.3154
# Epoch [   24/  500] | d_loss: 1.0774 | g_loss: 1.2757
# Epoch [   24/  500] | d_loss: 1.3113 | g_loss: 1.2258
# Epoch [   24/  500] | d_loss: 1.2765 | g_loss: 1.0368
# Epoch [   25/  500] | d_loss: 1.2921 | g_loss: 0.9475
# Epoch [   25/  500] | d_loss: 1.2527 | g_loss: 1.0159
# Epoch [   25/  500] | d_loss: 1.2412 | g_loss: 1.1594
# Epoch [   26/  500] | d_loss: 1.3201 | g_loss: 1.0580
# Epoch [   26/  500] | d_loss: 1.1383 | g_loss: 1.0701
# Epoch [   26/  500] | d_loss: 1.2166 | g_loss: 1.4360
# Epoch [   27/  500] | d_loss: 1.1406 | g_loss: 1.5710
# Epoch [   27/  500] | d_loss: 1.3226 | g_loss: 0.8732
# Epoch [   27/  500] | d_loss: 1.2442 | g_loss: 1.4512
# Epoch [   28/  500] | d_loss: 1.2377 | g_loss: 1.1974
# Epoch [   28/  500] | d_loss: 1.1254 | g_loss: 1.9427
# Epoch [   28/  500] | d_loss: 1.1938 | g_loss: 1.7119
# Epoch [   29/  500] | d_loss: 1.2603 | g_loss: 1.1286
# Epoch [   29/  500] | d_loss: 1.0997 | g_loss: 1.5291
# Epoch [   29/  500] | d_loss: 1.1998 | g_loss: 0.9778
# Epoch [   30/  500] | d_loss: 1.1921 | g_loss: 1.0795
# Epoch [   30/  500] | d_loss: 1.1304 | g_loss: 1.4217
# Epoch [   30/  500] | d_loss: 1.1393 | g_loss: 1.7788
# Epoch [   31/  500] | d_loss: 1.1646 | g_loss: 1.6626
# Epoch [   31/  500] | d_loss: 1.1875 | g_loss: 1.4954
# Epoch [   31/  500] | d_loss: 1.1086 | g_loss: 1.4519
# Epoch [   32/  500] | d_loss: 1.1732 | g_loss: 1.5989
# Epoch [   32/  500] | d_loss: 1.2861 | g_loss: 0.9520
# Epoch [   32/  500] | d_loss: 1.1700 | g_loss: 1.1521
# Epoch [   33/  500] | d_loss: 1.3947 | g_loss: 0.9738
# Epoch [   33/  500] | d_loss: 1.2190 | g_loss: 0.9067
# Epoch [   33/  500] | d_loss: 1.3783 | g_loss: 1.0914
# Epoch [   34/  500] | d_loss: 1.1787 | g_loss: 1.5933
# Epoch [   34/  500] | d_loss: 1.1899 | g_loss: 1.4419
# Epoch [   34/  500] | d_loss: 1.1633 | g_loss: 1.3277
# Epoch [   35/  500] | d_loss: 1.3771 | g_loss: 0.9745
# Epoch [   35/  500] | d_loss: 1.1870 | g_loss: 1.2977
# Epoch [   35/  500] | d_loss: 1.2176 | g_loss: 1.1020
# Epoch [   36/  500] | d_loss: 1.2790 | g_loss: 0.9696
# Epoch [   36/  500] | d_loss: 1.2786 | g_loss: 1.0426
# Epoch [   36/  500] | d_loss: 1.2498 | g_loss: 0.9648
# Epoch [   37/  500] | d_loss: 1.1568 | g_loss: 1.6255
# Epoch [   37/  500] | d_loss: 1.1686 | g_loss: 1.8363
# Epoch [   37/  500] | d_loss: 1.1106 | g_loss: 1.7267
# Epoch [   38/  500] | d_loss: 1.2501 | g_loss: 1.1383
# Epoch [   38/  500] | d_loss: 1.2755 | g_loss: 0.9259
# Epoch [   38/  500] | d_loss: 1.2808 | g_loss: 1.2082
# Epoch [   39/  500] | d_loss: 1.1692 | g_loss: 1.5946
# Epoch [   39/  500] | d_loss: 1.3073 | g_loss: 1.2240
# Epoch [   39/  500] | d_loss: 1.2969 | g_loss: 1.2243
# Epoch [   40/  500] | d_loss: 1.1409 | g_loss: 1.2961
# Epoch [   40/  500] | d_loss: 1.3152 | g_loss: 1.2863
# Epoch [   40/  500] | d_loss: 1.3149 | g_loss: 0.9785
# Epoch [   41/  500] | d_loss: 1.2254 | g_loss: 0.9414
# Epoch [   41/  500] | d_loss: 1.1513 | g_loss: 1.3875
# Epoch [   41/  500] | d_loss: 1.1849 | g_loss: 1.3521
# Epoch [   42/  500] | d_loss: 1.2794 | g_loss: 0.9502
# Epoch [   42/  500] | d_loss: 1.2454 | g_loss: 1.1589
# Epoch [   42/  500] | d_loss: 1.2364 | g_loss: 1.2619
# Epoch [   43/  500] | d_loss: 1.1407 | g_loss: 1.0455
# Epoch [   43/  500] | d_loss: 1.2729 | g_loss: 1.3774
# Epoch [   43/  500] | d_loss: 1.2670 | g_loss: 0.9626
# Epoch [   44/  500] | d_loss: 1.2070 | g_loss: 0.9024
# Epoch [   44/  500] | d_loss: 1.2286 | g_loss: 1.2555
# Epoch [   44/  500] | d_loss: 1.1813 | g_loss: 1.6602
# Epoch [   45/  500] | d_loss: 1.2529 | g_loss: 1.4244
# Epoch [   45/  500] | d_loss: 1.2271 | g_loss: 0.9557
# Epoch [   45/  500] | d_loss: 1.2489 | g_loss: 1.3443
# Epoch [   46/  500] | d_loss: 1.2837 | g_loss: 0.9722
# Epoch [   46/  500] | d_loss: 1.1875 | g_loss: 1.5411
# Epoch [   46/  500] | d_loss: 1.2640 | g_loss: 1.2788
# Epoch [   47/  500] | d_loss: 1.2996 | g_loss: 1.0563
# Epoch [   47/  500] | d_loss: 0.9606 | g_loss: 1.7215
# Epoch [   47/  500] | d_loss: 1.2082 | g_loss: 1.3988
# Epoch [   48/  500] | d_loss: 1.2374 | g_loss: 0.9904
# Epoch [   48/  500] | d_loss: 1.2917 | g_loss: 1.0072
# Epoch [   48/  500] | d_loss: 1.2398 | g_loss: 1.2497
# Epoch [   49/  500] | d_loss: 1.2462 | g_loss: 1.6793
# Epoch [   49/  500] | d_loss: 1.1601 | g_loss: 1.3052
# Epoch [   49/  500] | d_loss: 1.2032 | g_loss: 1.4055
# Epoch [   50/  500] | d_loss: 1.3347 | g_loss: 1.0851
# Epoch [   50/  500] | d_loss: 1.1806 | g_loss: 1.0654
# Epoch [   50/  500] | d_loss: 1.2234 | g_loss: 1.2160
# Epoch [   51/  500] | d_loss: 1.2289 | g_loss: 1.2980
# Epoch [   51/  500] | d_loss: 1.2903 | g_loss: 1.2546
# Epoch [   51/  500] | d_loss: 1.0707 | g_loss: 1.6577
# Epoch [   52/  500] | d_loss: 1.1878 | g_loss: 1.6363
# Epoch [   52/  500] | d_loss: 1.1649 | g_loss: 1.3544
# Epoch [   52/  500] | d_loss: 1.2144 | g_loss: 1.2000
# Epoch [   53/  500] | d_loss: 1.2630 | g_loss: 1.0635
# Epoch [   53/  500] | d_loss: 1.2609 | g_loss: 0.9037
# Epoch [   53/  500] | d_loss: 1.1512 | g_loss: 1.1684
# Epoch [   54/  500] | d_loss: 1.2485 | g_loss: 1.1295
# Epoch [   54/  500] | d_loss: 1.2371 | g_loss: 1.0436
# Epoch [   54/  500] | d_loss: 1.1725 | g_loss: 1.3592
# Epoch [   55/  500] | d_loss: 1.2517 | g_loss: 1.0760
# Epoch [   55/  500] | d_loss: 1.1886 | g_loss: 1.5219
# Epoch [   55/  500] | d_loss: 1.2923 | g_loss: 0.8935
# Epoch [   56/  500] | d_loss: 1.2878 | g_loss: 1.0093
# Epoch [   56/  500] | d_loss: 1.3542 | g_loss: 1.0654
# Epoch [   56/  500] | d_loss: 1.2595 | g_loss: 0.9841
# Epoch [   57/  500] | d_loss: 1.1018 | g_loss: 1.8571
# Epoch [   57/  500] | d_loss: 1.1390 | g_loss: 1.2370
# Epoch [   57/  500] | d_loss: 1.1504 | g_loss: 0.9683
# Epoch [   58/  500] | d_loss: 1.1717 | g_loss: 1.3139
# Epoch [   58/  500] | d_loss: 1.2665 | g_loss: 1.0386
# Epoch [   58/  500] | d_loss: 1.2873 | g_loss: 1.2526
# Epoch [   59/  500] | d_loss: 1.2662 | g_loss: 1.8850
# Epoch [   59/  500] | d_loss: 1.2679 | g_loss: 1.1945
# Epoch [   59/  500] | d_loss: 1.2535 | g_loss: 1.4648
# Epoch [   60/  500] | d_loss: 1.1889 | g_loss: 1.4266
# Epoch [   60/  500] | d_loss: 1.1474 | g_loss: 1.2425
# Epoch [   60/  500] | d_loss: 1.1978 | g_loss: 1.1326
# Epoch [   61/  500] | d_loss: 1.1592 | g_loss: 1.3801
# Epoch [   61/  500] | d_loss: 1.1591 | g_loss: 1.2772
# Epoch [   61/  500] | d_loss: 1.2720 | g_loss: 1.1389
# Epoch [   62/  500] | d_loss: 1.3596 | g_loss: 1.0779
# Epoch [   62/  500] | d_loss: 1.1480 | g_loss: 1.0497
# Epoch [   62/  500] | d_loss: 1.1873 | g_loss: 1.0690
# Epoch [   63/  500] | d_loss: 1.2169 | g_loss: 1.0181
# Epoch [   63/  500] | d_loss: 1.1455 | g_loss: 1.0573
# Epoch [   63/  500] | d_loss: 1.2772 | g_loss: 1.0918
# Epoch [   64/  500] | d_loss: 1.2198 | g_loss: 1.1610
# Epoch [   64/  500] | d_loss: 1.2859 | g_loss: 0.9409
# Epoch [   64/  500] | d_loss: 1.2280 | g_loss: 1.0722
# Epoch [   65/  500] | d_loss: 1.2860 | g_loss: 0.9500
# Epoch [   65/  500] | d_loss: 1.1725 | g_loss: 1.3575
# Epoch [   65/  500] | d_loss: 1.3266 | g_loss: 1.2183
# Epoch [   66/  500] | d_loss: 1.2236 | g_loss: 1.5462
# Epoch [   66/  500] | d_loss: 1.1828 | g_loss: 1.3684
# Epoch [   66/  500] | d_loss: 1.2909 | g_loss: 1.0773
# Epoch [   67/  500] | d_loss: 1.2215 | g_loss: 1.6014
# Epoch [   67/  500] | d_loss: 1.2427 | g_loss: 1.1229
# Epoch [   67/  500] | d_loss: 1.2795 | g_loss: 1.4069
# Epoch [   68/  500] | d_loss: 1.2159 | g_loss: 1.0709
# Epoch [   68/  500] | d_loss: 1.1672 | g_loss: 1.2628
# Epoch [   68/  500] | d_loss: 1.1437 | g_loss: 1.7521
# Epoch [   69/  500] | d_loss: 1.2106 | g_loss: 1.0995
# Epoch [   69/  500] | d_loss: 1.2065 | g_loss: 1.9199
# Epoch [   69/  500] | d_loss: 1.2932 | g_loss: 1.2587
# Epoch [   70/  500] | d_loss: 1.1841 | g_loss: 1.1175
# Epoch [   70/  500] | d_loss: 1.3847 | g_loss: 1.4071
# Epoch [   70/  500] | d_loss: 1.1806 | g_loss: 1.1526
# Epoch [   71/  500] | d_loss: 1.2453 | g_loss: 1.2221
# Epoch [   71/  500] | d_loss: 1.1567 | g_loss: 1.1623
# Epoch [   71/  500] | d_loss: 1.2718 | g_loss: 1.0485
# Epoch [   72/  500] | d_loss: 1.3033 | g_loss: 1.1852
# Epoch [   72/  500] | d_loss: 1.3254 | g_loss: 1.2854
# Epoch [   72/  500] | d_loss: 1.2563 | g_loss: 1.3695
# Epoch [   73/  500] | d_loss: 1.2883 | g_loss: 0.8750
# Epoch [   73/  500] | d_loss: 1.1395 | g_loss: 1.1526
# Epoch [   73/  500] | d_loss: 1.2037 | g_loss: 1.1854
# Epoch [   74/  500] | d_loss: 1.3386 | g_loss: 1.2473
# Epoch [   74/  500] | d_loss: 1.2520 | g_loss: 1.1902
# Epoch [   74/  500] | d_loss: 1.2247 | g_loss: 0.8602
# Epoch [   75/  500] | d_loss: 1.4072 | g_loss: 1.1667
# Epoch [   75/  500] | d_loss: 1.3879 | g_loss: 1.1368
# Epoch [   75/  500] | d_loss: 1.2610 | g_loss: 1.1202
# Epoch [   76/  500] | d_loss: 1.2146 | g_loss: 1.2063
# Epoch [   76/  500] | d_loss: 1.2243 | g_loss: 1.3251
# Epoch [   76/  500] | d_loss: 1.3167 | g_loss: 1.1024
# Epoch [   77/  500] | d_loss: 1.2267 | g_loss: 1.2807
# Epoch [   77/  500] | d_loss: 1.1956 | g_loss: 1.0389
# Epoch [   77/  500] | d_loss: 1.2619 | g_loss: 1.1788
# Epoch [   78/  500] | d_loss: 1.3102 | g_loss: 1.1064
# Epoch [   78/  500] | d_loss: 1.1825 | g_loss: 1.4155
# Epoch [   78/  500] | d_loss: 1.2305 | g_loss: 1.0312
# Epoch [   79/  500] | d_loss: 1.2210 | g_loss: 0.9475
# Epoch [   79/  500] | d_loss: 1.1970 | g_loss: 1.4100
# Epoch [   79/  500] | d_loss: 1.2744 | g_loss: 0.9419
# Epoch [   80/  500] | d_loss: 1.3544 | g_loss: 0.9948
# Epoch [   80/  500] | d_loss: 1.3079 | g_loss: 1.2014
# Epoch [   80/  500] | d_loss: 1.1694 | g_loss: 1.2034
# Epoch [   81/  500] | d_loss: 1.2060 | g_loss: 1.4288
# Epoch [   81/  500] | d_loss: 1.2503 | g_loss: 1.0642
# Epoch [   81/  500] | d_loss: 1.2301 | g_loss: 1.7698
# Epoch [   82/  500] | d_loss: 1.3411 | g_loss: 1.3322
# Epoch [   82/  500] | d_loss: 1.2192 | g_loss: 1.0931
# Epoch [   82/  500] | d_loss: 1.1427 | g_loss: 2.2372
# Epoch [   83/  500] | d_loss: 1.2849 | g_loss: 1.0868
# Epoch [   83/  500] | d_loss: 1.2125 | g_loss: 1.0084
# Epoch [   83/  500] | d_loss: 1.3023 | g_loss: 1.3738
# Epoch [   84/  500] | d_loss: 1.2412 | g_loss: 1.1197
# Epoch [   84/  500] | d_loss: 1.1430 | g_loss: 1.7330
# Epoch [   84/  500] | d_loss: 1.1123 | g_loss: 1.1259
# Epoch [   85/  500] | d_loss: 1.2154 | g_loss: 0.8792
# Epoch [   85/  500] | d_loss: 1.3530 | g_loss: 0.8825
# Epoch [   85/  500] | d_loss: 1.1196 | g_loss: 1.9070
# Epoch [   86/  500] | d_loss: 1.2175 | g_loss: 1.0745
# Epoch [   86/  500] | d_loss: 1.2498 | g_loss: 1.1944
# Epoch [   86/  500] | d_loss: 1.2594 | g_loss: 1.1680
# Epoch [   87/  500] | d_loss: 1.2645 | g_loss: 1.1822
# Epoch [   87/  500] | d_loss: 1.2413 | g_loss: 1.1109
# Epoch [   87/  500] | d_loss: 1.1925 | g_loss: 1.0370
# Epoch [   88/  500] | d_loss: 1.2276 | g_loss: 0.9625
# Epoch [   88/  500] | d_loss: 1.2309 | g_loss: 1.1301
# Epoch [   88/  500] | d_loss: 1.2539 | g_loss: 0.9772
# Epoch [   89/  500] | d_loss: 1.3287 | g_loss: 1.0324
# Epoch [   89/  500] | d_loss: 1.2525 | g_loss: 1.2876
# Epoch [   89/  500] | d_loss: 1.2463 | g_loss: 1.1061
# Epoch [   90/  500] | d_loss: 1.2218 | g_loss: 0.9893
# Epoch [   90/  500] | d_loss: 1.2049 | g_loss: 1.3501
# Epoch [   90/  500] | d_loss: 1.2758 | g_loss: 1.1325
# Epoch [   91/  500] | d_loss: 1.2143 | g_loss: 0.9051
# Epoch [   91/  500] | d_loss: 1.1426 | g_loss: 1.1409
# Epoch [   91/  500] | d_loss: 1.1570 | g_loss: 1.0712
# Epoch [   92/  500] | d_loss: 1.2205 | g_loss: 0.9889
# Epoch [   92/  500] | d_loss: 1.2205 | g_loss: 1.3681
# Epoch [   92/  500] | d_loss: 1.2901 | g_loss: 1.0154
# Epoch [   93/  500] | d_loss: 1.2662 | g_loss: 0.9476
# Epoch [   93/  500] | d_loss: 1.2194 | g_loss: 1.3492
# Epoch [   93/  500] | d_loss: 1.2738 | g_loss: 1.1456
# Epoch [   94/  500] | d_loss: 1.3355 | g_loss: 0.9617
# Epoch [   94/  500] | d_loss: 1.2120 | g_loss: 1.4550
# Epoch [   94/  500] | d_loss: 1.2516 | g_loss: 1.1400
# Epoch [   95/  500] | d_loss: 1.2173 | g_loss: 1.0716
# Epoch [   95/  500] | d_loss: 1.2306 | g_loss: 1.0057
# Epoch [   95/  500] | d_loss: 1.2125 | g_loss: 1.6127
# Epoch [   96/  500] | d_loss: 1.2785 | g_loss: 1.1209
# Epoch [   96/  500] | d_loss: 1.2115 | g_loss: 1.1617
# Epoch [   96/  500] | d_loss: 1.2883 | g_loss: 1.2361
# Epoch [   97/  500] | d_loss: 1.3518 | g_loss: 1.2054
# Epoch [   97/  500] | d_loss: 1.2322 | g_loss: 1.1293
# Epoch [   97/  500] | d_loss: 1.1404 | g_loss: 1.5641
# Epoch [   98/  500] | d_loss: 1.1534 | g_loss: 1.3518
# Epoch [   98/  500] | d_loss: 1.2458 | g_loss: 1.1070
# Epoch [   98/  500] | d_loss: 1.3402 | g_loss: 1.0774
# Epoch [   99/  500] | d_loss: 1.2452 | g_loss: 0.8419
# Epoch [   99/  500] | d_loss: 1.2462 | g_loss: 1.2436
# Epoch [   99/  500] | d_loss: 1.3060 | g_loss: 1.1131
# Epoch [  100/  500] | d_loss: 1.2800 | g_loss: 1.1905
# Epoch [  100/  500] | d_loss: 1.2569 | g_loss: 1.1361
# Epoch [  100/  500] | d_loss: 1.2567 | g_loss: 0.8723
# Epoch [  101/  500] | d_loss: 1.2850 | g_loss: 0.9682
# Epoch [  101/  500] | d_loss: 1.2184 | g_loss: 1.0997
# Epoch [  101/  500] | d_loss: 1.2912 | g_loss: 0.8552
# Epoch [  102/  500] | d_loss: 1.2706 | g_loss: 0.9503
# Epoch [  102/  500] | d_loss: 1.2782 | g_loss: 1.0681
# Epoch [  102/  500] | d_loss: 1.2007 | g_loss: 0.9678
# Epoch [  103/  500] | d_loss: 1.2469 | g_loss: 1.0161
# Epoch [  103/  500] | d_loss: 1.3089 | g_loss: 1.1875
# Epoch [  103/  500] | d_loss: 1.2285 | g_loss: 1.7595
# Epoch [  104/  500] | d_loss: 1.2533 | g_loss: 1.0659
# Epoch [  104/  500] | d_loss: 1.2605 | g_loss: 0.8501
# Epoch [  104/  500] | d_loss: 1.0797 | g_loss: 1.2305
# Epoch [  105/  500] | d_loss: 1.2763 | g_loss: 0.9296
# Epoch [  105/  500] | d_loss: 1.3354 | g_loss: 1.1980
# Epoch [  105/  500] | d_loss: 1.2070 | g_loss: 1.2492
# Epoch [  106/  500] | d_loss: 1.1645 | g_loss: 1.2565
# Epoch [  106/  500] | d_loss: 1.2600 | g_loss: 0.9077
# Epoch [  106/  500] | d_loss: 1.3628 | g_loss: 1.1093
# Epoch [  107/  500] | d_loss: 1.2648 | g_loss: 1.0085
# Epoch [  107/  500] | d_loss: 1.1214 | g_loss: 1.6613
# Epoch [  107/  500] | d_loss: 1.2012 | g_loss: 1.0202
# Epoch [  108/  500] | d_loss: 1.2412 | g_loss: 1.0897
# Epoch [  108/  500] | d_loss: 1.3382 | g_loss: 1.2132
# Epoch [  108/  500] | d_loss: 1.2813 | g_loss: 1.0203
# Epoch [  109/  500] | d_loss: 1.1664 | g_loss: 0.9630
# Epoch [  109/  500] | d_loss: 1.2967 | g_loss: 0.7849
# Epoch [  109/  500] | d_loss: 1.2394 | g_loss: 1.5510
# Epoch [  110/  500] | d_loss: 1.2599 | g_loss: 1.1246
# Epoch [  110/  500] | d_loss: 1.3391 | g_loss: 0.9522
# Epoch [  110/  500] | d_loss: 1.1563 | g_loss: 1.7419
# Epoch [  111/  500] | d_loss: 1.3601 | g_loss: 1.0447
# Epoch [  111/  500] | d_loss: 1.3258 | g_loss: 1.0195
# Epoch [  111/  500] | d_loss: 1.3118 | g_loss: 0.9174
# Epoch [  112/  500] | d_loss: 1.2693 | g_loss: 1.2186
# Epoch [  112/  500] | d_loss: 1.2580 | g_loss: 1.1928
# Epoch [  112/  500] | d_loss: 1.2218 | g_loss: 1.3464
# Epoch [  113/  500] | d_loss: 1.1806 | g_loss: 0.9713
# Epoch [  113/  500] | d_loss: 1.1703 | g_loss: 1.0758
# Epoch [  113/  500] | d_loss: 1.2869 | g_loss: 1.1168
# Epoch [  114/  500] | d_loss: 1.3036 | g_loss: 1.1918
# Epoch [  114/  500] | d_loss: 1.3047 | g_loss: 1.0023
# Epoch [  114/  500] | d_loss: 1.2759 | g_loss: 1.4156
# Epoch [  115/  500] | d_loss: 1.1840 | g_loss: 1.5440
# Epoch [  115/  500] | d_loss: 1.2348 | g_loss: 1.0649
# Epoch [  115/  500] | d_loss: 1.2919 | g_loss: 1.0302
# Epoch [  116/  500] | d_loss: 1.1615 | g_loss: 1.2047
# Epoch [  116/  500] | d_loss: 1.2177 | g_loss: 0.9573
# Epoch [  116/  500] | d_loss: 1.2610 | g_loss: 1.0390
# Epoch [  117/  500] | d_loss: 1.2907 | g_loss: 1.0181
# Epoch [  117/  500] | d_loss: 1.2564 | g_loss: 0.9245
# Epoch [  117/  500] | d_loss: 1.3164 | g_loss: 1.3418
# Epoch [  118/  500] | d_loss: 1.2368 | g_loss: 1.1640
# Epoch [  118/  500] | d_loss: 1.1178 | g_loss: 1.2921
# Epoch [  118/  500] | d_loss: 1.1610 | g_loss: 1.1586
# Epoch [  119/  500] | d_loss: 1.2246 | g_loss: 0.9894
# Epoch [  119/  500] | d_loss: 1.3133 | g_loss: 1.4735
# Epoch [  119/  500] | d_loss: 1.1779 | g_loss: 1.0206
# Epoch [  120/  500] | d_loss: 1.2174 | g_loss: 1.1304
# Epoch [  120/  500] | d_loss: 1.2534 | g_loss: 0.9985
# Epoch [  120/  500] | d_loss: 1.2806 | g_loss: 1.3785
# Epoch [  121/  500] | d_loss: 1.2064 | g_loss: 1.2973
# Epoch [  121/  500] | d_loss: 1.2729 | g_loss: 1.0025
# Epoch [  121/  500] | d_loss: 1.2264 | g_loss: 1.2614
# Epoch [  122/  500] | d_loss: 1.2584 | g_loss: 1.4948
# Epoch [  122/  500] | d_loss: 1.1490 | g_loss: 1.2090
# Epoch [  122/  500] | d_loss: 1.1740 | g_loss: 1.0600
# Epoch [  123/  500] | d_loss: 1.3155 | g_loss: 0.9902
# Epoch [  123/  500] | d_loss: 1.1318 | g_loss: 1.4319
# Epoch [  123/  500] | d_loss: 1.2511 | g_loss: 1.2390
# Epoch [  124/  500] | d_loss: 1.1405 | g_loss: 1.0102
# Epoch [  124/  500] | d_loss: 1.2777 | g_loss: 1.0411
# Epoch [  124/  500] | d_loss: 1.2056 | g_loss: 1.2179
# Epoch [  125/  500] | d_loss: 1.2428 | g_loss: 1.0596
# Epoch [  125/  500] | d_loss: 1.2450 | g_loss: 0.9275
# Epoch [  125/  500] | d_loss: 1.2182 | g_loss: 1.1429
# Epoch [  126/  500] | d_loss: 1.2536 | g_loss: 1.0062
# Epoch [  126/  500] | d_loss: 1.1717 | g_loss: 1.1896
# Epoch [  126/  500] | d_loss: 1.1554 | g_loss: 1.6853
# Epoch [  127/  500] | d_loss: 1.1724 | g_loss: 1.1623
# Epoch [  127/  500] | d_loss: 1.1709 | g_loss: 1.0357
# Epoch [  127/  500] | d_loss: 1.2175 | g_loss: 0.9364
# Epoch [  128/  500] | d_loss: 1.2432 | g_loss: 1.5318
# Epoch [  128/  500] | d_loss: 1.2811 | g_loss: 1.1572
# Epoch [  128/  500] | d_loss: 1.2687 | g_loss: 0.9932
# Epoch [  129/  500] | d_loss: 1.3207 | g_loss: 1.1105
# Epoch [  129/  500] | d_loss: 1.2041 | g_loss: 1.2156
# Epoch [  129/  500] | d_loss: 1.3252 | g_loss: 1.1367
# Epoch [  130/  500] | d_loss: 1.1714 | g_loss: 1.0630
# Epoch [  130/  500] | d_loss: 1.2601 | g_loss: 0.9216
# Epoch [  130/  500] | d_loss: 1.2630 | g_loss: 0.8567
# Epoch [  131/  500] | d_loss: 1.1798 | g_loss: 1.0625
# Epoch [  131/  500] | d_loss: 1.2805 | g_loss: 0.9317
# Epoch [  131/  500] | d_loss: 1.2822 | g_loss: 0.8910
# Epoch [  132/  500] | d_loss: 1.2416 | g_loss: 1.2863
# Epoch [  132/  500] | d_loss: 1.2627 | g_loss: 1.0505
# Epoch [  132/  500] | d_loss: 1.1947 | g_loss: 1.2598
# Epoch [  133/  500] | d_loss: 1.2279 | g_loss: 1.3825
# Epoch [  133/  500] | d_loss: 1.3076 | g_loss: 0.8287
# Epoch [  133/  500] | d_loss: 1.2630 | g_loss: 1.1018
# Epoch [  134/  500] | d_loss: 1.3182 | g_loss: 1.2609
# Epoch [  134/  500] | d_loss: 1.3150 | g_loss: 1.1418
# Epoch [  134/  500] | d_loss: 1.2279 | g_loss: 1.3458
# Epoch [  135/  500] | d_loss: 1.3547 | g_loss: 1.0321
# Epoch [  135/  500] | d_loss: 1.2475 | g_loss: 0.9458
# Epoch [  135/  500] | d_loss: 1.2022 | g_loss: 1.2030
# Epoch [  136/  500] | d_loss: 1.2841 | g_loss: 1.4943
# Epoch [  136/  500] | d_loss: 1.2772 | g_loss: 1.1561
# Epoch [  136/  500] | d_loss: 1.0407 | g_loss: 1.6557
# Epoch [  137/  500] | d_loss: 1.1511 | g_loss: 1.2667
# Epoch [  137/  500] | d_loss: 1.3392 | g_loss: 1.0588
# Epoch [  137/  500] | d_loss: 1.2258 | g_loss: 1.1689
# Epoch [  138/  500] | d_loss: 1.2195 | g_loss: 1.0739
# Epoch [  138/  500] | d_loss: 1.1672 | g_loss: 1.2001
# Epoch [  138/  500] | d_loss: 1.2312 | g_loss: 0.9979
# Epoch [  139/  500] | d_loss: 1.2693 | g_loss: 1.0553
# Epoch [  139/  500] | d_loss: 1.2721 | g_loss: 1.1736
# Epoch [  139/  500] | d_loss: 1.2537 | g_loss: 1.0049
# Epoch [  140/  500] | d_loss: 1.2092 | g_loss: 0.9870
# Epoch [  140/  500] | d_loss: 1.2492 | g_loss: 1.0326
# Epoch [  140/  500] | d_loss: 1.2686 | g_loss: 1.0468
# Epoch [  141/  500] | d_loss: 1.2884 | g_loss: 1.1977
# Epoch [  141/  500] | d_loss: 1.2185 | g_loss: 0.9895
# Epoch [  141/  500] | d_loss: 1.2253 | g_loss: 1.0930
# Epoch [  142/  500] | d_loss: 1.3833 | g_loss: 1.2352
# Epoch [  142/  500] | d_loss: 1.2453 | g_loss: 1.1004
# Epoch [  142/  500] | d_loss: 1.2879 | g_loss: 1.0547
# Epoch [  143/  500] | d_loss: 1.1524 | g_loss: 1.2511
# Epoch [  143/  500] | d_loss: 1.3118 | g_loss: 1.0846
# Epoch [  143/  500] | d_loss: 1.2338 | g_loss: 0.9489
# Epoch [  144/  500] | d_loss: 1.2979 | g_loss: 1.1397
# Epoch [  144/  500] | d_loss: 1.2926 | g_loss: 1.1743
# Epoch [  144/  500] | d_loss: 1.2835 | g_loss: 0.9840
# Epoch [  145/  500] | d_loss: 1.2392 | g_loss: 1.0347
# Epoch [  145/  500] | d_loss: 1.2467 | g_loss: 1.3121
# Epoch [  145/  500] | d_loss: 1.2347 | g_loss: 1.2773
# Epoch [  146/  500] | d_loss: 1.3209 | g_loss: 1.1768
# Epoch [  146/  500] | d_loss: 1.1457 | g_loss: 1.3300
# Epoch [  146/  500] | d_loss: 1.1424 | g_loss: 1.1426
# Epoch [  147/  500] | d_loss: 1.3982 | g_loss: 1.0734
# Epoch [  147/  500] | d_loss: 1.2933 | g_loss: 0.9763
# Epoch [  147/  500] | d_loss: 1.2470 | g_loss: 0.9495
# Epoch [  148/  500] | d_loss: 1.3372 | g_loss: 0.9317
# Epoch [  148/  500] | d_loss: 1.1650 | g_loss: 1.2338
# Epoch [  148/  500] | d_loss: 1.2055 | g_loss: 1.2728
# Epoch [  149/  500] | d_loss: 1.2492 | g_loss: 0.8877
# Epoch [  149/  500] | d_loss: 1.2469 | g_loss: 0.9515
# Epoch [  149/  500] | d_loss: 1.2387 | g_loss: 1.2609
# Epoch [  150/  500] | d_loss: 1.3273 | g_loss: 1.2420
# Epoch [  150/  500] | d_loss: 1.3102 | g_loss: 1.0908
# Epoch [  150/  500] | d_loss: 1.2998 | g_loss: 1.1727
# Epoch [  151/  500] | d_loss: 1.2153 | g_loss: 1.0041
# Epoch [  151/  500] | d_loss: 1.2336 | g_loss: 0.9903
# Epoch [  151/  500] | d_loss: 1.2030 | g_loss: 0.9803
# Epoch [  152/  500] | d_loss: 1.2535 | g_loss: 1.0105
# Epoch [  152/  500] | d_loss: 1.2207 | g_loss: 1.0452
# Epoch [  152/  500] | d_loss: 1.2864 | g_loss: 0.9413
# Epoch [  153/  500] | d_loss: 1.1756 | g_loss: 1.6437
# Epoch [  153/  500] | d_loss: 1.2514 | g_loss: 0.9771
# Epoch [  153/  500] | d_loss: 1.2546 | g_loss: 0.9806
# Epoch [  154/  500] | d_loss: 1.3101 | g_loss: 1.1739
# Epoch [  154/  500] | d_loss: 1.2576 | g_loss: 1.1150
# Epoch [  154/  500] | d_loss: 1.2774 | g_loss: 1.1886
# Epoch [  155/  500] | d_loss: 1.2694 | g_loss: 1.2667
# Epoch [  155/  500] | d_loss: 1.2691 | g_loss: 1.1531
# Epoch [  155/  500] | d_loss: 1.2463 | g_loss: 1.1686
# Epoch [  156/  500] | d_loss: 1.1763 | g_loss: 0.9590
# Epoch [  156/  500] | d_loss: 1.2269 | g_loss: 1.5306
# Epoch [  156/  500] | d_loss: 1.2515 | g_loss: 1.0539
# Epoch [  157/  500] | d_loss: 1.1799 | g_loss: 1.0532
# Epoch [  157/  500] | d_loss: 1.1218 | g_loss: 1.0606
# Epoch [  157/  500] | d_loss: 1.2483 | g_loss: 0.9936
# Epoch [  158/  500] | d_loss: 1.1672 | g_loss: 1.0223
# Epoch [  158/  500] | d_loss: 1.3075 | g_loss: 1.0636
# Epoch [  158/  500] | d_loss: 1.2396 | g_loss: 1.0801
# Epoch [  159/  500] | d_loss: 1.2588 | g_loss: 1.1875
# Epoch [  159/  500] | d_loss: 1.2316 | g_loss: 0.9094
# Epoch [  159/  500] | d_loss: 1.2489 | g_loss: 0.8584
# Epoch [  160/  500] | d_loss: 1.3034 | g_loss: 1.0561
# Epoch [  160/  500] | d_loss: 1.3073 | g_loss: 1.2368
# Epoch [  160/  500] | d_loss: 1.2004 | g_loss: 1.1030
# Epoch [  161/  500] | d_loss: 1.2429 | g_loss: 1.0316
# Epoch [  161/  500] | d_loss: 1.3630 | g_loss: 1.4600
# Epoch [  161/  500] | d_loss: 1.2812 | g_loss: 1.0089
# Epoch [  162/  500] | d_loss: 1.3357 | g_loss: 0.8630
# Epoch [  162/  500] | d_loss: 1.2252 | g_loss: 1.2097
# Epoch [  162/  500] | d_loss: 1.3286 | g_loss: 0.9950
# Epoch [  163/  500] | d_loss: 1.1461 | g_loss: 1.1464
# Epoch [  163/  500] | d_loss: 1.2771 | g_loss: 1.2312
# Epoch [  163/  500] | d_loss: 1.3434 | g_loss: 0.9875
# Epoch [  164/  500] | d_loss: 1.3209 | g_loss: 1.0897
# Epoch [  164/  500] | d_loss: 1.2573 | g_loss: 1.0572
# Epoch [  164/  500] | d_loss: 1.3067 | g_loss: 1.0389
# Epoch [  165/  500] | d_loss: 1.2388 | g_loss: 1.0653
# Epoch [  165/  500] | d_loss: 1.1881 | g_loss: 1.0176
# Epoch [  165/  500] | d_loss: 1.2453 | g_loss: 0.9558
# Epoch [  166/  500] | d_loss: 1.2819 | g_loss: 1.0950
# Epoch [  166/  500] | d_loss: 1.1971 | g_loss: 1.2182
# Epoch [  166/  500] | d_loss: 1.3039 | g_loss: 1.0769
# Epoch [  167/  500] | d_loss: 1.2444 | g_loss: 1.2969
# Epoch [  167/  500] | d_loss: 1.3371 | g_loss: 0.8712
# Epoch [  167/  500] | d_loss: 1.2850 | g_loss: 1.0449
# Epoch [  168/  500] | d_loss: 1.1997 | g_loss: 1.3525
# Epoch [  168/  500] | d_loss: 1.3262 | g_loss: 0.9912
# Epoch [  168/  500] | d_loss: 1.2849 | g_loss: 1.0499
# Epoch [  169/  500] | d_loss: 1.2779 | g_loss: 1.1836
# Epoch [  169/  500] | d_loss: 1.2778 | g_loss: 1.0175
# Epoch [  169/  500] | d_loss: 1.2530 | g_loss: 1.0330
# Epoch [  170/  500] | d_loss: 1.2768 | g_loss: 1.1203
# Epoch [  170/  500] | d_loss: 1.2212 | g_loss: 1.1365
# Epoch [  170/  500] | d_loss: 1.1703 | g_loss: 1.4833
# Epoch [  171/  500] | d_loss: 1.3012 | g_loss: 1.0670
# Epoch [  171/  500] | d_loss: 1.1795 | g_loss: 0.9010
# Epoch [  171/  500] | d_loss: 1.0646 | g_loss: 1.1971
# Epoch [  172/  500] | d_loss: 1.3047 | g_loss: 1.0501
# Epoch [  172/  500] | d_loss: 1.2708 | g_loss: 0.9966
# Epoch [  172/  500] | d_loss: 1.2967 | g_loss: 1.0565
# Epoch [  173/  500] | d_loss: 1.3905 | g_loss: 0.9928
# Epoch [  173/  500] | d_loss: 1.2322 | g_loss: 0.9909
# Epoch [  173/  500] | d_loss: 1.1879 | g_loss: 1.3039
# Epoch [  174/  500] | d_loss: 1.2638 | g_loss: 1.1283
# Epoch [  174/  500] | d_loss: 1.3058 | g_loss: 1.3442
# Epoch [  174/  500] | d_loss: 1.2145 | g_loss: 1.4211
# Epoch [  175/  500] | d_loss: 1.4009 | g_loss: 1.1922
# Epoch [  175/  500] | d_loss: 1.1646 | g_loss: 1.1782
# Epoch [  175/  500] | d_loss: 1.2912 | g_loss: 1.1574
# Epoch [  176/  500] | d_loss: 1.2881 | g_loss: 1.1600
# Epoch [  176/  500] | d_loss: 1.2485 | g_loss: 1.2347
# Epoch [  176/  500] | d_loss: 1.3182 | g_loss: 1.1187
# Epoch [  177/  500] | d_loss: 1.3034 | g_loss: 1.0547
# Epoch [  177/  500] | d_loss: 1.3010 | g_loss: 0.9937
# Epoch [  177/  500] | d_loss: 1.2888 | g_loss: 0.9413
# Epoch [  178/  500] | d_loss: 1.2659 | g_loss: 1.1340
# Epoch [  178/  500] | d_loss: 1.2299 | g_loss: 0.9474
# Epoch [  178/  500] | d_loss: 1.2025 | g_loss: 1.3048
# Epoch [  179/  500] | d_loss: 1.1815 | g_loss: 1.1069
# Epoch [  179/  500] | d_loss: 1.2718 | g_loss: 0.9813
# Epoch [  179/  500] | d_loss: 1.2462 | g_loss: 0.9614
# Epoch [  180/  500] | d_loss: 1.2426 | g_loss: 1.1678
# Epoch [  180/  500] | d_loss: 1.1487 | g_loss: 1.0750
# Epoch [  180/  500] | d_loss: 1.2426 | g_loss: 1.2294
# Epoch [  181/  500] | d_loss: 1.2273 | g_loss: 1.0992
# Epoch [  181/  500] | d_loss: 1.2216 | g_loss: 1.0180
# Epoch [  181/  500] | d_loss: 1.1524 | g_loss: 1.4971
# Epoch [  182/  500] | d_loss: 1.2404 | g_loss: 1.1246
# Epoch [  182/  500] | d_loss: 1.2323 | g_loss: 1.2072
# Epoch [  182/  500] | d_loss: 1.1909 | g_loss: 1.2197
# Epoch [  183/  500] | d_loss: 1.1949 | g_loss: 1.3270
# Epoch [  183/  500] | d_loss: 1.2523 | g_loss: 1.1816
# Epoch [  183/  500] | d_loss: 1.2608 | g_loss: 1.1767
# Epoch [  184/  500] | d_loss: 1.1705 | g_loss: 1.1123
# Epoch [  184/  500] | d_loss: 1.2849 | g_loss: 0.9587
# Epoch [  184/  500] | d_loss: 1.3819 | g_loss: 1.0370
# Epoch [  185/  500] | d_loss: 1.3616 | g_loss: 1.1221
# Epoch [  185/  500] | d_loss: 1.1929 | g_loss: 0.9605
# Epoch [  185/  500] | d_loss: 1.2232 | g_loss: 1.0992
# Epoch [  186/  500] | d_loss: 1.1483 | g_loss: 1.1453
# Epoch [  186/  500] | d_loss: 1.2665 | g_loss: 0.9989
# Epoch [  186/  500] | d_loss: 1.3412 | g_loss: 1.0498
# Epoch [  187/  500] | d_loss: 1.1429 | g_loss: 1.2615
# Epoch [  187/  500] | d_loss: 1.2550 | g_loss: 0.9827
# Epoch [  187/  500] | d_loss: 1.2983 | g_loss: 1.1974
# Epoch [  188/  500] | d_loss: 1.3832 | g_loss: 1.0706
# Epoch [  188/  500] | d_loss: 1.2771 | g_loss: 1.2175
# Epoch [  188/  500] | d_loss: 1.1758 | g_loss: 0.9965
# Epoch [  189/  500] | d_loss: 1.1900 | g_loss: 1.0515
# Epoch [  189/  500] | d_loss: 1.2647 | g_loss: 0.9802
# Epoch [  189/  500] | d_loss: 1.3018 | g_loss: 0.9930
# Epoch [  190/  500] | d_loss: 1.2759 | g_loss: 1.0165
# Epoch [  190/  500] | d_loss: 1.3378 | g_loss: 0.8784
# Epoch [  190/  500] | d_loss: 1.2729 | g_loss: 0.9320
# Epoch [  191/  500] | d_loss: 1.3734 | g_loss: 1.1759
# Epoch [  191/  500] | d_loss: 1.3841 | g_loss: 1.1740
# Epoch [  191/  500] | d_loss: 1.2099 | g_loss: 1.3964
# Epoch [  192/  500] | d_loss: 1.2338 | g_loss: 1.1541
# Epoch [  192/  500] | d_loss: 1.1727 | g_loss: 1.3057
# Epoch [  192/  500] | d_loss: 1.2528 | g_loss: 1.1203
# Epoch [  193/  500] | d_loss: 1.2492 | g_loss: 1.0867
# Epoch [  193/  500] | d_loss: 1.2665 | g_loss: 0.9944
# Epoch [  193/  500] | d_loss: 1.3914 | g_loss: 1.1021
# Epoch [  194/  500] | d_loss: 1.3799 | g_loss: 1.1072
# Epoch [  194/  500] | d_loss: 1.2676 | g_loss: 1.1368
# Epoch [  194/  500] | d_loss: 1.3868 | g_loss: 1.0644
# Epoch [  195/  500] | d_loss: 1.2772 | g_loss: 0.8786
# Epoch [  195/  500] | d_loss: 1.3158 | g_loss: 1.1596
# Epoch [  195/  500] | d_loss: 1.2270 | g_loss: 1.0509
# Epoch [  196/  500] | d_loss: 1.3065 | g_loss: 1.0938
# Epoch [  196/  500] | d_loss: 1.3703 | g_loss: 1.1183
# Epoch [  196/  500] | d_loss: 1.2447 | g_loss: 1.2110
# Epoch [  197/  500] | d_loss: 1.2633 | g_loss: 0.9558
# Epoch [  197/  500] | d_loss: 1.2156 | g_loss: 1.3836
# Epoch [  197/  500] | d_loss: 1.2492 | g_loss: 0.9362
# Epoch [  198/  500] | d_loss: 1.2363 | g_loss: 1.1810
# Epoch [  198/  500] | d_loss: 1.3317 | g_loss: 0.7745
# Epoch [  198/  500] | d_loss: 1.2788 | g_loss: 1.0886
# Epoch [  199/  500] | d_loss: 1.2657 | g_loss: 1.0790
# Epoch [  199/  500] | d_loss: 1.3319 | g_loss: 1.0071
# Epoch [  199/  500] | d_loss: 1.3381 | g_loss: 1.1288
# Epoch [  200/  500] | d_loss: 1.3291 | g_loss: 1.5228
# Epoch [  200/  500] | d_loss: 1.1696 | g_loss: 1.1137
# Epoch [  200/  500] | d_loss: 1.2070 | g_loss: 1.0766
# Epoch [  201/  500] | d_loss: 1.2878 | g_loss: 0.9910
# Epoch [  201/  500] | d_loss: 1.2060 | g_loss: 1.1170
# Epoch [  201/  500] | d_loss: 1.3860 | g_loss: 1.0006
# Epoch [  202/  500] | d_loss: 1.3008 | g_loss: 1.0399
# Epoch [  202/  500] | d_loss: 1.3021 | g_loss: 0.8668
# Epoch [  202/  500] | d_loss: 1.3440 | g_loss: 1.0901
# Epoch [  203/  500] | d_loss: 1.3001 | g_loss: 0.9442
# Epoch [  203/  500] | d_loss: 1.3369 | g_loss: 1.0429
# Epoch [  203/  500] | d_loss: 1.2967 | g_loss: 1.0292
# Epoch [  204/  500] | d_loss: 1.2182 | g_loss: 1.1673
# Epoch [  204/  500] | d_loss: 1.3648 | g_loss: 1.0687
# Epoch [  204/  500] | d_loss: 1.2372 | g_loss: 1.1494
# Epoch [  205/  500] | d_loss: 1.2681 | g_loss: 1.1508
# Epoch [  205/  500] | d_loss: 1.2483 | g_loss: 0.8869
# Epoch [  205/  500] | d_loss: 1.3768 | g_loss: 1.4518
# Epoch [  206/  500] | d_loss: 1.3549 | g_loss: 1.3413
# Epoch [  206/  500] | d_loss: 1.2406 | g_loss: 1.0496
# Epoch [  206/  500] | d_loss: 1.2688 | g_loss: 1.0314
# Epoch [  207/  500] | d_loss: 1.3839 | g_loss: 1.1695
# Epoch [  207/  500] | d_loss: 1.2762 | g_loss: 0.9957
# Epoch [  207/  500] | d_loss: 1.2841 | g_loss: 1.0999
# Epoch [  208/  500] | d_loss: 1.1982 | g_loss: 1.2751
# Epoch [  208/  500] | d_loss: 1.2829 | g_loss: 1.0336
# Epoch [  208/  500] | d_loss: 1.3518 | g_loss: 0.8755
# Epoch [  209/  500] | d_loss: 1.2498 | g_loss: 1.0990
# Epoch [  209/  500] | d_loss: 1.2791 | g_loss: 1.0031
# Epoch [  209/  500] | d_loss: 1.2973 | g_loss: 1.1547
# Epoch [  210/  500] | d_loss: 1.2509 | g_loss: 1.0911
# Epoch [  210/  500] | d_loss: 1.2303 | g_loss: 1.0329
# Epoch [  210/  500] | d_loss: 1.3985 | g_loss: 1.3809
# Epoch [  211/  500] | d_loss: 1.3154 | g_loss: 1.3992
# Epoch [  211/  500] | d_loss: 1.1984 | g_loss: 1.2204
# Epoch [  211/  500] | d_loss: 1.3019 | g_loss: 1.3464
# Epoch [  212/  500] | d_loss: 1.3691 | g_loss: 1.4823
# Epoch [  212/  500] | d_loss: 1.3119 | g_loss: 1.0372
# Epoch [  212/  500] | d_loss: 1.2549 | g_loss: 1.1645
# Epoch [  213/  500] | d_loss: 1.2682 | g_loss: 1.0651
# Epoch [  213/  500] | d_loss: 1.1503 | g_loss: 1.0211
# Epoch [  213/  500] | d_loss: 1.2646 | g_loss: 1.6452
# Epoch [  214/  500] | d_loss: 1.2318 | g_loss: 1.0761
# Epoch [  214/  500] | d_loss: 1.2279 | g_loss: 1.1381
# Epoch [  214/  500] | d_loss: 1.3017 | g_loss: 1.2179
# Epoch [  215/  500] | d_loss: 1.2821 | g_loss: 0.8415
# Epoch [  215/  500] | d_loss: 1.2870 | g_loss: 0.9880
# Epoch [  215/  500] | d_loss: 1.2483 | g_loss: 0.9688
# Epoch [  216/  500] | d_loss: 1.2248 | g_loss: 1.1864
# Epoch [  216/  500] | d_loss: 1.2541 | g_loss: 1.3125
# Epoch [  216/  500] | d_loss: 1.1841 | g_loss: 1.2062
# Epoch [  217/  500] | d_loss: 1.3307 | g_loss: 1.0785
# Epoch [  217/  500] | d_loss: 1.1977 | g_loss: 1.0208
# Epoch [  217/  500] | d_loss: 1.2212 | g_loss: 1.0091
# Epoch [  218/  500] | d_loss: 1.2875 | g_loss: 1.1303
# Epoch [  218/  500] | d_loss: 1.2794 | g_loss: 1.0498
# Epoch [  218/  500] | d_loss: 1.1548 | g_loss: 0.9409
# Epoch [  219/  500] | d_loss: 1.3576 | g_loss: 0.9324
# Epoch [  219/  500] | d_loss: 1.2452 | g_loss: 1.1009
# Epoch [  219/  500] | d_loss: 1.3696 | g_loss: 1.0432
# Epoch [  220/  500] | d_loss: 1.1069 | g_loss: 1.0805
# Epoch [  220/  500] | d_loss: 1.3121 | g_loss: 1.0195
# Epoch [  220/  500] | d_loss: 1.2218 | g_loss: 1.0234
# Epoch [  221/  500] | d_loss: 1.2467 | g_loss: 1.1129
# Epoch [  221/  500] | d_loss: 1.2398 | g_loss: 0.9867
# Epoch [  221/  500] | d_loss: 1.2673 | g_loss: 1.1050
# Epoch [  222/  500] | d_loss: 1.3823 | g_loss: 1.1728
# Epoch [  222/  500] | d_loss: 1.3787 | g_loss: 1.0244
# Epoch [  222/  500] | d_loss: 1.2379 | g_loss: 1.0053
# Epoch [  223/  500] | d_loss: 1.3180 | g_loss: 1.1028
# Epoch [  223/  500] | d_loss: 1.2559 | g_loss: 1.1775
# Epoch [  223/  500] | d_loss: 1.2393 | g_loss: 0.8917
# Epoch [  224/  500] | d_loss: 1.2589 | g_loss: 0.8801
# Epoch [  224/  500] | d_loss: 1.2668 | g_loss: 1.0326
# Epoch [  224/  500] | d_loss: 1.3087 | g_loss: 1.1397
# Epoch [  225/  500] | d_loss: 1.1801 | g_loss: 1.0188
# Epoch [  225/  500] | d_loss: 1.2505 | g_loss: 0.9379
# Epoch [  225/  500] | d_loss: 1.3476 | g_loss: 1.0526
# Epoch [  226/  500] | d_loss: 1.2957 | g_loss: 1.1544
# Epoch [  226/  500] | d_loss: 1.2288 | g_loss: 0.8182
# Epoch [  226/  500] | d_loss: 1.2142 | g_loss: 1.0875
# Epoch [  227/  500] | d_loss: 1.2093 | g_loss: 1.2324
# Epoch [  227/  500] | d_loss: 1.2075 | g_loss: 1.1152
# Epoch [  227/  500] | d_loss: 1.2402 | g_loss: 1.1639
# Epoch [  228/  500] | d_loss: 1.2802 | g_loss: 1.1430
# Epoch [  228/  500] | d_loss: 1.2613 | g_loss: 0.9831
# Epoch [  228/  500] | d_loss: 1.2611 | g_loss: 1.1488
# Epoch [  229/  500] | d_loss: 1.3057 | g_loss: 0.9062
# Epoch [  229/  500] | d_loss: 1.3253 | g_loss: 1.1373
# Epoch [  229/  500] | d_loss: 1.2734 | g_loss: 1.1984
# Epoch [  230/  500] | d_loss: 1.1375 | g_loss: 1.0380
# Epoch [  230/  500] | d_loss: 1.2776 | g_loss: 1.2491
# Epoch [  230/  500] | d_loss: 1.2126 | g_loss: 1.0655
# Epoch [  231/  500] | d_loss: 1.3316 | g_loss: 1.1513
# Epoch [  231/  500] | d_loss: 1.2573 | g_loss: 1.1770
# Epoch [  231/  500] | d_loss: 1.2713 | g_loss: 1.0554
# Epoch [  232/  500] | d_loss: 1.2394 | g_loss: 1.1140
# Epoch [  232/  500] | d_loss: 1.2158 | g_loss: 0.9855
# Epoch [  232/  500] | d_loss: 1.1906 | g_loss: 1.3701
# Epoch [  233/  500] | d_loss: 1.1992 | g_loss: 0.9924
# Epoch [  233/  500] | d_loss: 1.1532 | g_loss: 1.5243
# Epoch [  233/  500] | d_loss: 1.2020 | g_loss: 0.9875
# Epoch [  234/  500] | d_loss: 1.2758 | g_loss: 1.4933
# Epoch [  234/  500] | d_loss: 1.2267 | g_loss: 1.0386
# Epoch [  234/  500] | d_loss: 1.1229 | g_loss: 1.1789
# Epoch [  235/  500] | d_loss: 1.1981 | g_loss: 1.1376
# Epoch [  235/  500] | d_loss: 1.3683 | g_loss: 1.2762
# Epoch [  235/  500] | d_loss: 1.2318 | g_loss: 1.0905
# Epoch [  236/  500] | d_loss: 1.3237 | g_loss: 1.0632
# Epoch [  236/  500] | d_loss: 1.1835 | g_loss: 1.0901
# Epoch [  236/  500] | d_loss: 1.3130 | g_loss: 0.9581
# Epoch [  237/  500] | d_loss: 1.2186 | g_loss: 0.9576
# Epoch [  237/  500] | d_loss: 1.2580 | g_loss: 1.2630
# Epoch [  237/  500] | d_loss: 1.2810 | g_loss: 1.2323
# Epoch [  238/  500] | d_loss: 1.3160 | g_loss: 1.1200
# Epoch [  238/  500] | d_loss: 1.2661 | g_loss: 0.9854
# Epoch [  238/  500] | d_loss: 1.2548 | g_loss: 0.8704
# Epoch [  239/  500] | d_loss: 1.3170 | g_loss: 0.9973
# Epoch [  239/  500] | d_loss: 1.2433 | g_loss: 0.9073
# Epoch [  239/  500] | d_loss: 1.2421 | g_loss: 1.0926
# Epoch [  240/  500] | d_loss: 1.3492 | g_loss: 1.0036
# Epoch [  240/  500] | d_loss: 1.2679 | g_loss: 1.0457
# Epoch [  240/  500] | d_loss: 1.2438 | g_loss: 1.0857
# Epoch [  241/  500] | d_loss: 1.2024 | g_loss: 1.3440
# Epoch [  241/  500] | d_loss: 1.2061 | g_loss: 1.2064
# Epoch [  241/  500] | d_loss: 1.2549 | g_loss: 0.9641
# Epoch [  242/  500] | d_loss: 1.4375 | g_loss: 1.0765
# Epoch [  242/  500] | d_loss: 1.2608 | g_loss: 1.0270
# Epoch [  242/  500] | d_loss: 1.4028 | g_loss: 1.2811
# Epoch [  243/  500] | d_loss: 1.3417 | g_loss: 0.9970
# Epoch [  243/  500] | d_loss: 1.2378 | g_loss: 1.4928
# Epoch [  243/  500] | d_loss: 1.2102 | g_loss: 1.2361
# Epoch [  244/  500] | d_loss: 1.3045 | g_loss: 1.0293
# Epoch [  244/  500] | d_loss: 1.2773 | g_loss: 1.0196
# Epoch [  244/  500] | d_loss: 1.3148 | g_loss: 1.0242
# Epoch [  245/  500] | d_loss: 1.3638 | g_loss: 0.8637
# Epoch [  245/  500] | d_loss: 1.1988 | g_loss: 1.1865
# Epoch [  245/  500] | d_loss: 1.3364 | g_loss: 1.0651
# Epoch [  246/  500] | d_loss: 1.3275 | g_loss: 1.0494
# Epoch [  246/  500] | d_loss: 1.2439 | g_loss: 0.9033
# Epoch [  246/  500] | d_loss: 1.2793 | g_loss: 1.1637
# Epoch [  247/  500] | d_loss: 1.2370 | g_loss: 1.0056
# Epoch [  247/  500] | d_loss: 1.2236 | g_loss: 1.1385
# Epoch [  247/  500] | d_loss: 1.2190 | g_loss: 1.0725
# Epoch [  248/  500] | d_loss: 1.3483 | g_loss: 0.9922
# Epoch [  248/  500] | d_loss: 1.2627 | g_loss: 1.1865
# Epoch [  248/  500] | d_loss: 1.2654 | g_loss: 1.2506
# Epoch [  249/  500] | d_loss: 1.2827 | g_loss: 1.0071
# Epoch [  249/  500] | d_loss: 1.3770 | g_loss: 0.9343
# Epoch [  249/  500] | d_loss: 1.2718 | g_loss: 1.0963
# Epoch [  250/  500] | d_loss: 1.2979 | g_loss: 1.0474
# Epoch [  250/  500] | d_loss: 1.3140 | g_loss: 0.9372
# Epoch [  250/  500] | d_loss: 1.3323 | g_loss: 1.0455
# Epoch [  251/  500] | d_loss: 1.2504 | g_loss: 0.9985
# Epoch [  251/  500] | d_loss: 1.2965 | g_loss: 1.1207
# Epoch [  251/  500] | d_loss: 1.3286 | g_loss: 1.1256
# Epoch [  252/  500] | d_loss: 1.2277 | g_loss: 1.2036
# Epoch [  252/  500] | d_loss: 1.2793 | g_loss: 1.0690
# Epoch [  252/  500] | d_loss: 1.2290 | g_loss: 0.9550
# Epoch [  253/  500] | d_loss: 1.2672 | g_loss: 1.1651
# Epoch [  253/  500] | d_loss: 1.2360 | g_loss: 1.0067
# Epoch [  253/  500] | d_loss: 1.2597 | g_loss: 0.8889
# Epoch [  254/  500] | d_loss: 1.2833 | g_loss: 0.9059
# Epoch [  254/  500] | d_loss: 1.3572 | g_loss: 1.0106
# Epoch [  254/  500] | d_loss: 1.3320 | g_loss: 1.1441
# Epoch [  255/  500] | d_loss: 1.2511 | g_loss: 1.0001
# Epoch [  255/  500] | d_loss: 1.2204 | g_loss: 1.1645
# Epoch [  255/  500] | d_loss: 1.2929 | g_loss: 1.0747
# Epoch [  256/  500] | d_loss: 1.2212 | g_loss: 1.0411
# Epoch [  256/  500] | d_loss: 1.2786 | g_loss: 1.0876
# Epoch [  256/  500] | d_loss: 1.2044 | g_loss: 1.1090
# Epoch [  257/  500] | d_loss: 1.2859 | g_loss: 0.8766
# Epoch [  257/  500] | d_loss: 1.2550 | g_loss: 1.0445
# Epoch [  257/  500] | d_loss: 1.1549 | g_loss: 1.1343
# Epoch [  258/  500] | d_loss: 1.2489 | g_loss: 0.9361
# Epoch [  258/  500] | d_loss: 1.2765 | g_loss: 1.0802
# Epoch [  258/  500] | d_loss: 1.2572 | g_loss: 1.0138
# Epoch [  259/  500] | d_loss: 1.2503 | g_loss: 1.0839
# Epoch [  259/  500] | d_loss: 1.2529 | g_loss: 0.9986
# Epoch [  259/  500] | d_loss: 1.2844 | g_loss: 0.9844
# Epoch [  260/  500] | d_loss: 1.1822 | g_loss: 1.2795
# Epoch [  260/  500] | d_loss: 1.2196 | g_loss: 1.2447
# Epoch [  260/  500] | d_loss: 1.2020 | g_loss: 1.0102
# Epoch [  261/  500] | d_loss: 1.3219 | g_loss: 0.9722
# Epoch [  261/  500] | d_loss: 1.2591 | g_loss: 1.0435
# Epoch [  261/  500] | d_loss: 1.2170 | g_loss: 0.9961
# Epoch [  262/  500] | d_loss: 1.2570 | g_loss: 1.0175
# Epoch [  262/  500] | d_loss: 1.2932 | g_loss: 0.9399
# Epoch [  262/  500] | d_loss: 1.2184 | g_loss: 1.0728
# Epoch [  263/  500] | d_loss: 1.3283 | g_loss: 0.9551
# Epoch [  263/  500] | d_loss: 1.2617 | g_loss: 1.1129
# Epoch [  263/  500] | d_loss: 1.2631 | g_loss: 1.0341
# Epoch [  264/  500] | d_loss: 1.2218 | g_loss: 1.1713
# Epoch [  264/  500] | d_loss: 1.2213 | g_loss: 0.8584
# Epoch [  264/  500] | d_loss: 1.2612 | g_loss: 0.8849
# Epoch [  265/  500] | d_loss: 1.2610 | g_loss: 1.1764
# Epoch [  265/  500] | d_loss: 1.3354 | g_loss: 1.0136
# Epoch [  265/  500] | d_loss: 1.3041 | g_loss: 0.9511
# Epoch [  266/  500] | d_loss: 1.3081 | g_loss: 1.2004
# Epoch [  266/  500] | d_loss: 1.3263 | g_loss: 1.0322
# Epoch [  266/  500] | d_loss: 1.3062 | g_loss: 1.0423
# Epoch [  267/  500] | d_loss: 1.3362 | g_loss: 1.2002
# Epoch [  267/  500] | d_loss: 1.2289 | g_loss: 0.9596
# Epoch [  267/  500] | d_loss: 1.2456 | g_loss: 0.8784
# Epoch [  268/  500] | d_loss: 1.4827 | g_loss: 1.0821
# Epoch [  268/  500] | d_loss: 1.3310 | g_loss: 1.1180
# Epoch [  268/  500] | d_loss: 1.2154 | g_loss: 1.0613
# Epoch [  269/  500] | d_loss: 1.2869 | g_loss: 0.9757
# Epoch [  269/  500] | d_loss: 1.2083 | g_loss: 1.4473
# Epoch [  269/  500] | d_loss: 1.1188 | g_loss: 1.5289
# Epoch [  270/  500] | d_loss: 1.4025 | g_loss: 1.1226
# Epoch [  270/  500] | d_loss: 1.2233 | g_loss: 0.9017
# Epoch [  270/  500] | d_loss: 1.2683 | g_loss: 1.0504
# Epoch [  271/  500] | d_loss: 1.2750 | g_loss: 1.0074
# Epoch [  271/  500] | d_loss: 1.2614 | g_loss: 1.0164
# Epoch [  271/  500] | d_loss: 1.2613 | g_loss: 1.0391
# Epoch [  272/  500] | d_loss: 1.2339 | g_loss: 1.0979
# Epoch [  272/  500] | d_loss: 1.3053 | g_loss: 0.9021
# Epoch [  272/  500] | d_loss: 1.2984 | g_loss: 1.0263
# Epoch [  273/  500] | d_loss: 1.2762 | g_loss: 1.2836
# Epoch [  273/  500] | d_loss: 1.2727 | g_loss: 1.2002
# Epoch [  273/  500] | d_loss: 1.2826 | g_loss: 1.0670
# Epoch [  274/  500] | d_loss: 1.2946 | g_loss: 0.9614
# Epoch [  274/  500] | d_loss: 1.2715 | g_loss: 1.0826
# Epoch [  274/  500] | d_loss: 1.2199 | g_loss: 1.1748
# Epoch [  275/  500] | d_loss: 1.2463 | g_loss: 0.9890
# Epoch [  275/  500] | d_loss: 1.2591 | g_loss: 0.9242
# Epoch [  275/  500] | d_loss: 1.2803 | g_loss: 1.0560
# Epoch [  276/  500] | d_loss: 1.2989 | g_loss: 0.9411
# Epoch [  276/  500] | d_loss: 1.3175 | g_loss: 0.9100
# Epoch [  276/  500] | d_loss: 1.2563 | g_loss: 1.0090
# Epoch [  277/  500] | d_loss: 1.2837 | g_loss: 1.1903
# Epoch [  277/  500] | d_loss: 1.1962 | g_loss: 1.1949
# Epoch [  277/  500] | d_loss: 1.1815 | g_loss: 1.1838
# Epoch [  278/  500] | d_loss: 1.1634 | g_loss: 1.1312
# Epoch [  278/  500] | d_loss: 1.1993 | g_loss: 1.0416
# Epoch [  278/  500] | d_loss: 1.2010 | g_loss: 1.0118
# Epoch [  279/  500] | d_loss: 1.1755 | g_loss: 1.2158
# Epoch [  279/  500] | d_loss: 1.1905 | g_loss: 1.1749
# Epoch [  279/  500] | d_loss: 1.1553 | g_loss: 0.9933
# Epoch [  280/  500] | d_loss: 1.3237 | g_loss: 1.1113
# Epoch [  280/  500] | d_loss: 1.2985 | g_loss: 1.1235
# Epoch [  280/  500] | d_loss: 1.3065 | g_loss: 1.3460
# Epoch [  281/  500] | d_loss: 1.2036 | g_loss: 1.1455
# Epoch [  281/  500] | d_loss: 1.2377 | g_loss: 1.2319
# Epoch [  281/  500] | d_loss: 1.2569 | g_loss: 1.2689
# Epoch [  282/  500] | d_loss: 1.3693 | g_loss: 1.0290
# Epoch [  282/  500] | d_loss: 1.2759 | g_loss: 1.0950
# Epoch [  282/  500] | d_loss: 1.2364 | g_loss: 1.2002
# Epoch [  283/  500] | d_loss: 1.1736 | g_loss: 1.1581
# Epoch [  283/  500] | d_loss: 1.2865 | g_loss: 1.1099
# Epoch [  283/  500] | d_loss: 1.2703 | g_loss: 1.3579
# Epoch [  284/  500] | d_loss: 1.3120 | g_loss: 1.0471
# Epoch [  284/  500] | d_loss: 1.3229 | g_loss: 1.1875
# Epoch [  284/  500] | d_loss: 1.3022 | g_loss: 1.0816
# Epoch [  285/  500] | d_loss: 1.2390 | g_loss: 1.1109
# Epoch [  285/  500] | d_loss: 1.3734 | g_loss: 0.9628
# Epoch [  285/  500] | d_loss: 1.2562 | g_loss: 1.1502
# Epoch [  286/  500] | d_loss: 1.2087 | g_loss: 1.1651
# Epoch [  286/  500] | d_loss: 1.4436 | g_loss: 1.2141
# Epoch [  286/  500] | d_loss: 1.2099 | g_loss: 0.9653
# Epoch [  287/  500] | d_loss: 1.2335 | g_loss: 0.9464
# Epoch [  287/  500] | d_loss: 1.2757 | g_loss: 0.9427
# Epoch [  287/  500] | d_loss: 1.1862 | g_loss: 1.1968
# Epoch [  288/  500] | d_loss: 1.2588 | g_loss: 1.0565
# Epoch [  288/  500] | d_loss: 1.2866 | g_loss: 1.0997
# Epoch [  288/  500] | d_loss: 1.2173 | g_loss: 0.9202
# Epoch [  289/  500] | d_loss: 1.1989 | g_loss: 1.1651
# Epoch [  289/  500] | d_loss: 1.2696 | g_loss: 1.1339
# Epoch [  289/  500] | d_loss: 1.2298 | g_loss: 1.0174
# Epoch [  290/  500] | d_loss: 1.2636 | g_loss: 1.0511
# Epoch [  290/  500] | d_loss: 1.3056 | g_loss: 1.1033
# Epoch [  290/  500] | d_loss: 1.0679 | g_loss: 1.4235
# Epoch [  291/  500] | d_loss: 1.2079 | g_loss: 1.0901
# Epoch [  291/  500] | d_loss: 1.2814 | g_loss: 0.9934
# Epoch [  291/  500] | d_loss: 1.2619 | g_loss: 1.1582
# Epoch [  292/  500] | d_loss: 1.2493 | g_loss: 1.1296
# Epoch [  292/  500] | d_loss: 1.2563 | g_loss: 1.1746
# Epoch [  292/  500] | d_loss: 1.2208 | g_loss: 1.2531
# Epoch [  293/  500] | d_loss: 1.1880 | g_loss: 1.0925
# Epoch [  293/  500] | d_loss: 1.3132 | g_loss: 0.9736
# Epoch [  293/  500] | d_loss: 1.2032 | g_loss: 1.1506
# Epoch [  294/  500] | d_loss: 1.2314 | g_loss: 1.1207
# Epoch [  294/  500] | d_loss: 1.2140 | g_loss: 1.1688
# Epoch [  294/  500] | d_loss: 1.3155 | g_loss: 1.2700
# Epoch [  295/  500] | d_loss: 1.2408 | g_loss: 0.9897
# Epoch [  295/  500] | d_loss: 1.2686 | g_loss: 1.1164
# ...
# Epoch [  402/  500] | d_loss: 1.3267 | g_loss: 0.9673
# Epoch [  402/  500] | d_loss: 1.2264 | g_loss: 1.0451
# Epoch [  403/  500] | d_loss: 1.1459 | g_loss: 0.9634
# Epoch [  403/  500] | d_loss: 1.1387 | g_loss: 1.1919
# Epoch [  403/  500] | d_loss: 1.3872 | g_loss: 1.0754
# Epoch [  404/  500] | d_loss: 1.2362 | g_loss: 1.0372
# Epoch [  404/  500] | d_loss: 1.2803 | g_loss: 1.0692
# Epoch [  404/  500] | d_loss: 1.2611 | g_loss: 1.1088
# Epoch [  405/  500] | d_loss: 1.3707 | g_loss: 1.1088
# Epoch [  405/  500] | d_loss: 1.2976 | g_loss: 1.0926
# Epoch [  405/  500] | d_loss: 1.2130 | g_loss: 1.0091
# Epoch [  406/  500] | d_loss: 1.3038 | g_loss: 1.1947
# Epoch [  406/  500] | d_loss: 1.3254 | g_loss: 0.9734
# Epoch [  406/  500] | d_loss: 1.3366 | g_loss: 1.0910
# Epoch [  407/  500] | d_loss: 1.3715 | g_loss: 1.1640
# Epoch [  407/  500] | d_loss: 1.1890 | g_loss: 1.1352
# Epoch [  407/  500] | d_loss: 1.2075 | g_loss: 1.0935
# Epoch [  408/  500] | d_loss: 1.2950 | g_loss: 1.5282
# Epoch [  408/  500] | d_loss: 1.2695 | g_loss: 1.0504
# Epoch [  408/  500] | d_loss: 1.3235 | g_loss: 1.2260
# Epoch [  409/  500] | d_loss: 1.2339 | g_loss: 1.0680
# Epoch [  409/  500] | d_loss: 1.2074 | g_loss: 0.8909
# Epoch [  409/  500] | d_loss: 1.2562 | g_loss: 1.1188
# Epoch [  410/  500] | d_loss: 1.2804 | g_loss: 1.0220
# Epoch [  410/  500] | d_loss: 1.2810 | g_loss: 1.1056
# Epoch [  410/  500] | d_loss: 1.2518 | g_loss: 0.9202
# Epoch [  411/  500] | d_loss: 1.2238 | g_loss: 0.9845
# Epoch [  411/  500] | d_loss: 1.3310 | g_loss: 1.0639
# Epoch [  411/  500] | d_loss: 1.2671 | g_loss: 1.0783
# Epoch [  412/  500] | d_loss: 1.3994 | g_loss: 1.0213
# Epoch [  412/  500] | d_loss: 1.2857 | g_loss: 1.1264
# Epoch [  412/  500] | d_loss: 1.2586 | g_loss: 1.0171
# Epoch [  413/  500] | d_loss: 1.4304 | g_loss: 1.2290
# Epoch [  413/  500] | d_loss: 1.2534 | g_loss: 1.0451
# Epoch [  413/  500] | d_loss: 1.2937 | g_loss: 1.0473
# Epoch [  414/  500] | d_loss: 1.2275 | g_loss: 1.0637
# Epoch [  414/  500] | d_loss: 1.2433 | g_loss: 0.9828
# Epoch [  414/  500] | d_loss: 1.3235 | g_loss: 1.0085
# Epoch [  415/  500] | d_loss: 1.3199 | g_loss: 1.2120
# Epoch [  415/  500] | d_loss: 1.2389 | g_loss: 0.9974
# Epoch [  415/  500] | d_loss: 1.2519 | g_loss: 0.9317
# Epoch [  416/  500] | d_loss: 1.2182 | g_loss: 1.1800
# Epoch [  416/  500] | d_loss: 1.1608 | g_loss: 1.1696
# Epoch [  416/  500] | d_loss: 1.2236 | g_loss: 0.9739
# Epoch [  417/  500] | d_loss: 1.2838 | g_loss: 1.1903
# Epoch [  417/  500] | d_loss: 1.3520 | g_loss: 1.1669
# Epoch [  417/  500] | d_loss: 1.2908 | g_loss: 1.1435
# Epoch [  418/  500] | d_loss: 1.2555 | g_loss: 1.1011
# Epoch [  418/  500] | d_loss: 1.2744 | g_loss: 0.9359
# Epoch [  418/  500] | d_loss: 1.2907 | g_loss: 1.1440
# Epoch [  419/  500] | d_loss: 1.2991 | g_loss: 1.0671
# Epoch [  419/  500] | d_loss: 1.3465 | g_loss: 1.2207
# Epoch [  419/  500] | d_loss: 1.3265 | g_loss: 1.4053
# Epoch [  420/  500] | d_loss: 1.3019 | g_loss: 1.1044
# Epoch [  420/  500] | d_loss: 1.3503 | g_loss: 1.0360
# Epoch [  420/  500] | d_loss: 1.2368 | g_loss: 1.0626
# Epoch [  421/  500] | d_loss: 1.3759 | g_loss: 1.1071
# Epoch [  421/  500] | d_loss: 1.3002 | g_loss: 0.9943
# Epoch [  421/  500] | d_loss: 1.2161 | g_loss: 1.0212
# Epoch [  422/  500] | d_loss: 1.2698 | g_loss: 1.1892
# Epoch [  422/  500] | d_loss: 1.2709 | g_loss: 0.9180
# Epoch [  422/  500] | d_loss: 1.1635 | g_loss: 1.0217
# Epoch [  423/  500] | d_loss: 1.2343 | g_loss: 0.9862
# Epoch [  423/  500] | d_loss: 1.2452 | g_loss: 1.1551
# Epoch [  423/  500] | d_loss: 1.2625 | g_loss: 0.9608
# Epoch [  424/  500] | d_loss: 1.2912 | g_loss: 0.9807
# Epoch [  424/  500] | d_loss: 1.1753 | g_loss: 1.0784
# Epoch [  424/  500] | d_loss: 1.2186 | g_loss: 0.9479
# Epoch [  425/  500] | d_loss: 1.4300 | g_loss: 0.9859
# Epoch [  425/  500] | d_loss: 1.2166 | g_loss: 1.3030
# Epoch [  425/  500] | d_loss: 1.2356 | g_loss: 1.1157
# Epoch [  426/  500] | d_loss: 1.2714 | g_loss: 1.2610
# Epoch [  426/  500] | d_loss: 1.3125 | g_loss: 1.3428
# Epoch [  426/  500] | d_loss: 1.2203 | g_loss: 1.0731
# Epoch [  427/  500] | d_loss: 1.2297 | g_loss: 1.2146
# Epoch [  427/  500] | d_loss: 1.2461 | g_loss: 1.0215
# Epoch [  427/  500] | d_loss: 1.2984 | g_loss: 1.0589
# Epoch [  428/  500] | d_loss: 1.2482 | g_loss: 1.1668
# Epoch [  428/  500] | d_loss: 1.3358 | g_loss: 0.9915
# Epoch [  428/  500] | d_loss: 1.3247 | g_loss: 1.1157
# Epoch [  429/  500] | d_loss: 1.3625 | g_loss: 1.1678
# Epoch [  429/  500] | d_loss: 1.2936 | g_loss: 1.0761
# Epoch [  429/  500] | d_loss: 1.1945 | g_loss: 1.2093
# Epoch [  430/  500] | d_loss: 1.3289 | g_loss: 1.0965
# Epoch [  430/  500] | d_loss: 1.2326 | g_loss: 1.1275
# Epoch [  430/  500] | d_loss: 1.2562 | g_loss: 1.1987
# Epoch [  431/  500] | d_loss: 1.2843 | g_loss: 0.9341
# Epoch [  431/  500] | d_loss: 1.2606 | g_loss: 1.0502
# Epoch [  431/  500] | d_loss: 1.2526 | g_loss: 1.1677
# Epoch [  432/  500] | d_loss: 1.2629 | g_loss: 0.9980
# Epoch [  432/  500] | d_loss: 1.2732 | g_loss: 1.0014
# Epoch [  432/  500] | d_loss: 1.2326 | g_loss: 1.1062
# Epoch [  433/  500] | d_loss: 1.2036 | g_loss: 0.9875
# Epoch [  433/  500] | d_loss: 1.3226 | g_loss: 1.1725
# Epoch [  433/  500] | d_loss: 1.2353 | g_loss: 1.0381
# Epoch [  434/  500] | d_loss: 1.3174 | g_loss: 1.1822
# Epoch [  434/  500] | d_loss: 1.2414 | g_loss: 1.2444
# Epoch [  434/  500] | d_loss: 1.2779 | g_loss: 1.1189
# Epoch [  435/  500] | d_loss: 1.2009 | g_loss: 1.2431
# Epoch [  435/  500] | d_loss: 1.2434 | g_loss: 1.0217
# Epoch [  435/  500] | d_loss: 1.3346 | g_loss: 0.9619
# Epoch [  436/  500] | d_loss: 1.2604 | g_loss: 1.3132
# Epoch [  436/  500] | d_loss: 1.2820 | g_loss: 1.0912
# Epoch [  436/  500] | d_loss: 1.2291 | g_loss: 1.0662
# Epoch [  437/  500] | d_loss: 1.1945 | g_loss: 1.1467
# Epoch [  437/  500] | d_loss: 1.1821 | g_loss: 1.0846
# Epoch [  437/  500] | d_loss: 1.2267 | g_loss: 1.1155
# Epoch [  438/  500] | d_loss: 1.4283 | g_loss: 1.2091
# Epoch [  438/  500] | d_loss: 1.2799 | g_loss: 1.0317
# Epoch [  438/  500] | d_loss: 1.2695 | g_loss: 1.0129
# Epoch [  439/  500] | d_loss: 1.3086 | g_loss: 0.9785
# Epoch [  439/  500] | d_loss: 1.2912 | g_loss: 1.1096
# Epoch [  439/  500] | d_loss: 1.3062 | g_loss: 1.1179
# Epoch [  440/  500] | d_loss: 1.2068 | g_loss: 1.0926
# Epoch [  440/  500] | d_loss: 1.2333 | g_loss: 1.1805
# Epoch [  440/  500] | d_loss: 1.2205 | g_loss: 1.0473
# Epoch [  441/  500] | d_loss: 1.3030 | g_loss: 1.0060
# Epoch [  441/  500] | d_loss: 1.1876 | g_loss: 0.9551
# Epoch [  441/  500] | d_loss: 1.2579 | g_loss: 1.0383
# Epoch [  442/  500] | d_loss: 1.3115 | g_loss: 1.1209
# Epoch [  442/  500] | d_loss: 1.2548 | g_loss: 1.0642
# Epoch [  442/  500] | d_loss: 1.1941 | g_loss: 1.2037
# Epoch [  443/  500] | d_loss: 1.3685 | g_loss: 1.0793
# Epoch [  443/  500] | d_loss: 1.2175 | g_loss: 1.1861
# Epoch [  443/  500] | d_loss: 1.2789 | g_loss: 1.1123
# Epoch [  444/  500] | d_loss: 1.3112 | g_loss: 1.1133
# Epoch [  444/  500] | d_loss: 1.3479 | g_loss: 1.0016
# Epoch [  444/  500] | d_loss: 1.2618 | g_loss: 1.1413
# Epoch [  445/  500] | d_loss: 1.1888 | g_loss: 1.1037
# Epoch [  445/  500] | d_loss: 1.2266 | g_loss: 1.2237
# Epoch [  445/  500] | d_loss: 1.3403 | g_loss: 1.0012
# Epoch [  446/  500] | d_loss: 1.2423 | g_loss: 1.0275
# Epoch [  446/  500] | d_loss: 1.2510 | g_loss: 0.9034
# Epoch [  446/  500] | d_loss: 1.3006 | g_loss: 1.0896
# Epoch [  447/  500] | d_loss: 1.2221 | g_loss: 1.0993
# Epoch [  447/  500] | d_loss: 1.2779 | g_loss: 1.3288
# Epoch [  447/  500] | d_loss: 1.1933 | g_loss: 1.1292
# Epoch [  448/  500] | d_loss: 1.2326 | g_loss: 1.0351
# Epoch [  448/  500] | d_loss: 1.2327 | g_loss: 1.0592
# Epoch [  448/  500] | d_loss: 1.2807 | g_loss: 1.0254
# Epoch [  449/  500] | d_loss: 1.2631 | g_loss: 1.0916
# Epoch [  449/  500] | d_loss: 1.2302 | g_loss: 1.1405
# Epoch [  449/  500] | d_loss: 1.2714 | g_loss: 1.1661
# Epoch [  450/  500] | d_loss: 1.3408 | g_loss: 1.0814
# Epoch [  450/  500] | d_loss: 1.2927 | g_loss: 1.0912
# Epoch [  450/  500] | d_loss: 1.1559 | g_loss: 1.1694
# Epoch [  451/  500] | d_loss: 1.2691 | g_loss: 0.9210
# Epoch [  451/  500] | d_loss: 1.2456 | g_loss: 0.8834
# Epoch [  451/  500] | d_loss: 1.3525 | g_loss: 1.2606
# Epoch [  452/  500] | d_loss: 1.3043 | g_loss: 1.0690
# Epoch [  452/  500] | d_loss: 1.3030 | g_loss: 1.0264
# Epoch [  452/  500] | d_loss: 1.1673 | g_loss: 1.0621
# Epoch [  453/  500] | d_loss: 1.1964 | g_loss: 1.1270
# Epoch [  453/  500] | d_loss: 1.2705 | g_loss: 0.9786
# Epoch [  453/  500] | d_loss: 1.2621 | g_loss: 1.1235
# Epoch [  454/  500] | d_loss: 1.1888 | g_loss: 1.1288
# Epoch [  454/  500] | d_loss: 1.2472 | g_loss: 1.0308
# Epoch [  454/  500] | d_loss: 1.2586 | g_loss: 1.0857
# Epoch [  455/  500] | d_loss: 1.2633 | g_loss: 1.2216
# Epoch [  455/  500] | d_loss: 1.1816 | g_loss: 1.0811
# Epoch [  455/  500] | d_loss: 1.2119 | g_loss: 1.0547
# Epoch [  456/  500] | d_loss: 1.2170 | g_loss: 1.1461
# Epoch [  456/  500] | d_loss: 1.2360 | g_loss: 1.1936
# Epoch [  456/  500] | d_loss: 1.1522 | g_loss: 1.0858
# Epoch [  457/  500] | d_loss: 1.3399 | g_loss: 1.0225
# Epoch [  457/  500] | d_loss: 1.2074 | g_loss: 1.0522
# Epoch [  457/  500] | d_loss: 1.2797 | g_loss: 1.1967
# Epoch [  458/  500] | d_loss: 1.2775 | g_loss: 1.1294
# Epoch [  458/  500] | d_loss: 1.3106 | g_loss: 1.1380
# Epoch [  458/  500] | d_loss: 1.2757 | g_loss: 1.0469
# Epoch [  459/  500] | d_loss: 1.2810 | g_loss: 0.9964
# Epoch [  459/  500] | d_loss: 1.1677 | g_loss: 1.1538
# Epoch [  459/  500] | d_loss: 1.2425 | g_loss: 1.0938
# Epoch [  460/  500] | d_loss: 1.2290 | g_loss: 0.9975
# Epoch [  460/  500] | d_loss: 1.3764 | g_loss: 1.1486
# Epoch [  460/  500] | d_loss: 1.2411 | g_loss: 1.1481
# Epoch [  461/  500] | d_loss: 1.1088 | g_loss: 1.1608
# Epoch [  461/  500] | d_loss: 1.1649 | g_loss: 1.1446
# Epoch [  461/  500] | d_loss: 1.2688 | g_loss: 1.0429
# Epoch [  462/  500] | d_loss: 1.2115 | g_loss: 1.0597
# Epoch [  462/  500] | d_loss: 1.2250 | g_loss: 1.0993
# Epoch [  462/  500] | d_loss: 1.1497 | g_loss: 1.4549
# Epoch [  463/  500] | d_loss: 1.2049 | g_loss: 1.2603
# Epoch [  463/  500] | d_loss: 1.3192 | g_loss: 0.9899
# Epoch [  463/  500] | d_loss: 1.2893 | g_loss: 1.1893
# Epoch [  464/  500] | d_loss: 1.1939 | g_loss: 1.3543
# Epoch [  464/  500] | d_loss: 1.1877 | g_loss: 1.1142
# Epoch [  464/  500] | d_loss: 1.1623 | g_loss: 1.1587
# Epoch [  465/  500] | d_loss: 1.1925 | g_loss: 1.2146
# Epoch [  465/  500] | d_loss: 1.3097 | g_loss: 1.1407
# Epoch [  465/  500] | d_loss: 1.2046 | g_loss: 0.9884
# Epoch [  466/  500] | d_loss: 1.2549 | g_loss: 1.1883
# Epoch [  466/  500] | d_loss: 1.3888 | g_loss: 1.2580
# Epoch [  466/  500] | d_loss: 1.2402 | g_loss: 1.3985
# Epoch [  467/  500] | d_loss: 1.3530 | g_loss: 1.1188
# Epoch [  467/  500] | d_loss: 1.2246 | g_loss: 1.1237
# Epoch [  467/  500] | d_loss: 1.2985 | g_loss: 1.0351
# Epoch [  468/  500] | d_loss: 1.3113 | g_loss: 0.9493
# Epoch [  468/  500] | d_loss: 1.2233 | g_loss: 1.0116
# Epoch [  468/  500] | d_loss: 1.3674 | g_loss: 1.1330
# Epoch [  469/  500] | d_loss: 1.3633 | g_loss: 1.0630
# Epoch [  469/  500] | d_loss: 1.2951 | g_loss: 1.1129
# Epoch [  469/  500] | d_loss: 1.2830 | g_loss: 1.1357
# Epoch [  470/  500] | d_loss: 1.1693 | g_loss: 1.1571
# Epoch [  470/  500] | d_loss: 1.2435 | g_loss: 1.2107
# Epoch [  470/  500] | d_loss: 1.3383 | g_loss: 1.0776
# Epoch [  471/  500] | d_loss: 1.2045 | g_loss: 1.1534
# Epoch [  471/  500] | d_loss: 1.1251 | g_loss: 1.2836
# Epoch [  471/  500] | d_loss: 1.2273 | g_loss: 1.0912
# Epoch [  472/  500] | d_loss: 1.1812 | g_loss: 1.0808
# Epoch [  472/  500] | d_loss: 1.2236 | g_loss: 1.2251
# Epoch [  472/  500] | d_loss: 1.2866 | g_loss: 1.1022
# Epoch [  473/  500] | d_loss: 1.3414 | g_loss: 1.2175
# Epoch [  473/  500] | d_loss: 1.2782 | g_loss: 1.0892
# Epoch [  473/  500] | d_loss: 1.2264 | g_loss: 1.0656
# Epoch [  474/  500] | d_loss: 1.1355 | g_loss: 1.2720
# Epoch [  474/  500] | d_loss: 1.1920 | g_loss: 1.2109
# Epoch [  474/  500] | d_loss: 1.3156 | g_loss: 1.0095
# Epoch [  475/  500] | d_loss: 1.2119 | g_loss: 1.1758
# Epoch [  475/  500] | d_loss: 1.2543 | g_loss: 1.0329
# Epoch [  475/  500] | d_loss: 1.3141 | g_loss: 1.0810
# Epoch [  476/  500] | d_loss: 1.2145 | g_loss: 1.2202
# Epoch [  476/  500] | d_loss: 1.2089 | g_loss: 1.2958
# Epoch [  476/  500] | d_loss: 1.1878 | g_loss: 1.1432
# Epoch [  477/  500] | d_loss: 1.2603 | g_loss: 1.0633
# Epoch [  477/  500] | d_loss: 1.2312 | g_loss: 1.0050
# Epoch [  477/  500] | d_loss: 1.2099 | g_loss: 1.1935
# Epoch [  478/  500] | d_loss: 1.0932 | g_loss: 1.4668
# Epoch [  478/  500] | d_loss: 1.2538 | g_loss: 1.0792
# Epoch [  478/  500] | d_loss: 1.3046 | g_loss: 0.9883
# Epoch [  479/  500] | d_loss: 1.3384 | g_loss: 1.1337
# Epoch [  479/  500] | d_loss: 1.3022 | g_loss: 0.8665
# Epoch [  479/  500] | d_loss: 1.2168 | g_loss: 1.0384
# Epoch [  480/  500] | d_loss: 1.1686 | g_loss: 1.1290
# Epoch [  480/  500] | d_loss: 1.2130 | g_loss: 1.2711
# Epoch [  480/  500] | d_loss: 1.2105 | g_loss: 1.1852
# Epoch [  481/  500] | d_loss: 1.2634 | g_loss: 1.3340
# Epoch [  481/  500] | d_loss: 1.2390 | g_loss: 1.2525
# Epoch [  481/  500] | d_loss: 1.2624 | g_loss: 1.1691
# Epoch [  482/  500] | d_loss: 1.3024 | g_loss: 1.0546
# Epoch [  482/  500] | d_loss: 1.2590 | g_loss: 1.2378
# Epoch [  482/  500] | d_loss: 1.3003 | g_loss: 1.0928
# Epoch [  483/  500] | d_loss: 1.3397 | g_loss: 1.0384
# Epoch [  483/  500] | d_loss: 1.2310 | g_loss: 1.2693
# Epoch [  483/  500] | d_loss: 1.2399 | g_loss: 1.0844
# Epoch [  484/  500] | d_loss: 1.1392 | g_loss: 1.0848
# Epoch [  484/  500] | d_loss: 1.1668 | g_loss: 1.1151
# Epoch [  484/  500] | d_loss: 1.1912 | g_loss: 1.0715
# Epoch [  485/  500] | d_loss: 1.1222 | g_loss: 1.2291
# Epoch [  485/  500] | d_loss: 1.2938 | g_loss: 1.2271
# Epoch [  485/  500] | d_loss: 1.2834 | g_loss: 1.1710
# Epoch [  486/  500] | d_loss: 1.2058 | g_loss: 1.1531
# Epoch [  486/  500] | d_loss: 1.1866 | g_loss: 1.1028
# Epoch [  486/  500] | d_loss: 1.3539 | g_loss: 1.1767
# Epoch [  487/  500] | d_loss: 1.1983 | g_loss: 1.2172
# Epoch [  487/  500] | d_loss: 1.2570 | g_loss: 0.9275
# Epoch [  487/  500] | d_loss: 1.2118 | g_loss: 1.0697
# Epoch [  488/  500] | d_loss: 1.2839 | g_loss: 1.0765
# Epoch [  488/  500] | d_loss: 1.2600 | g_loss: 1.0281
# Epoch [  488/  500] | d_loss: 1.2907 | g_loss: 1.0748
# Epoch [  489/  500] | d_loss: 1.1754 | g_loss: 1.1343
# Epoch [  489/  500] | d_loss: 1.1881 | g_loss: 1.1309
# Epoch [  489/  500] | d_loss: 1.2729 | g_loss: 1.2803
# Epoch [  490/  500] | d_loss: 1.2568 | g_loss: 1.2041
# Epoch [  490/  500] | d_loss: 1.2864 | g_loss: 1.0591
# Epoch [  490/  500] | d_loss: 1.4036 | g_loss: 1.1151
# Epoch [  491/  500] | d_loss: 1.3001 | g_loss: 1.1926
# Epoch [  491/  500] | d_loss: 1.2939 | g_loss: 1.0538
# Epoch [  491/  500] | d_loss: 1.3412 | g_loss: 1.1331
# Epoch [  492/  500] | d_loss: 1.2198 | g_loss: 1.1864
# Epoch [  492/  500] | d_loss: 1.2054 | g_loss: 1.2081
# Epoch [  492/  500] | d_loss: 1.2122 | g_loss: 1.1391
# Epoch [  493/  500] | d_loss: 1.2090 | g_loss: 1.1056
# Epoch [  493/  500] | d_loss: 1.2575 | g_loss: 1.0786
# Epoch [  493/  500] | d_loss: 1.2125 | g_loss: 1.0492
# Epoch [  494/  500] | d_loss: 1.1974 | g_loss: 1.0121
# Epoch [  494/  500] | d_loss: 1.1120 | g_loss: 1.5888
# Epoch [  494/  500] | d_loss: 1.2954 | g_loss: 0.9432
# Epoch [  495/  500] | d_loss: 1.1050 | g_loss: 1.1510
# Epoch [  495/  500] | d_loss: 1.2612 | g_loss: 1.3808
# Epoch [  495/  500] | d_loss: 1.2411 | g_loss: 0.9651
# Epoch [  496/  500] | d_loss: 1.2277 | g_loss: 1.1819
# Epoch [  496/  500] | d_loss: 1.2724 | g_loss: 1.0165
# Epoch [  496/  500] | d_loss: 1.2477 | g_loss: 1.1764
# Epoch [  497/  500] | d_loss: 1.3123 | g_loss: 1.2317
# Epoch [  497/  500] | d_loss: 1.2503 | g_loss: 1.1469
# Epoch [  497/  500] | d_loss: 1.2624 | g_loss: 1.1077
# Epoch [  498/  500] | d_loss: 1.2759 | g_loss: 1.0377
# Epoch [  498/  500] | d_loss: 1.1916 | g_loss: 1.0281
# Epoch [  498/  500] | d_loss: 1.2952 | g_loss: 0.8863
# Epoch [  499/  500] | d_loss: 1.2608 | g_loss: 1.1513
# Epoch [  499/  500] | d_loss: 1.2211 | g_loss: 1.1453
# Epoch [  499/  500] | d_loss: 1.2333 | g_loss: 1.2727
# Epoch [  500/  500] | d_loss: 1.2277 | g_loss: 1.2533
# Epoch [  500/  500] | d_loss: 1.2212 | g_loss: 0.9895
# Epoch [  500/  500] | d_loss: 1.2332 | g_loss: 1.0645

# %% [markdown]
# ## Training loss
#
# Here we'll plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator')
plt.plot(losses.T[1], label='Generator')
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# Here we can view samples of images from the generator. First we'll look at the images we saved during training.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(7,7), nrows=4, ncols=4, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach()
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((28,28)), cmap='Greys_r')

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %% [markdown]
# These are samples from the final training epoch. You can see the generator is able to reproduce numbers like 1, 7, 3, 2. Since this is just a sample, it isn't representative of the full range of images this generator can make.

# %%
# -1 indicates final epoch's samples (the last in the list)
view_samples(-1, samples)

# %% [markdown]
# Below I'm showing the generated images as the network was training, every 10 epochs.

# %%
rows = 10 # split epochs into 10, so 100/10 = every 10 epochs
cols = 6
fig, axes = plt.subplots(figsize=(7,12), nrows=rows, ncols=cols, sharex=True, sharey=True)

for sample, ax_row in zip(samples[::int(len(samples)/rows)], axes):
    for img, ax in zip(sample[::int(len(sample)/cols)], ax_row):
        img = img.detach()
        ax.imshow(img.reshape((28,28)), cmap='Greys_r')
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)

# %% [markdown]
# It starts out as all noise. Then it learns to make only the center white and the rest black. You can start to see some number like structures appear out of the noise like 1s and 9s.

# %% [markdown]
# ## Sampling from the generator
#
# We can also get completely new images from the generator by using the checkpoint we saved after training. **We just need to pass in a new latent vector $z$ and we'll get new samples**!

# %%
# randomly generated, new latent vectors
sample_size=16
rand_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
rand_z = torch.from_numpy(rand_z).float()

G.eval() # eval mode
# generated samples
rand_images = G(rand_z)

# 0 indicates the first set of samples in the passed in list
# and we only have one batch of samples, here
view_samples(0, [rand_images])
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1340: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
